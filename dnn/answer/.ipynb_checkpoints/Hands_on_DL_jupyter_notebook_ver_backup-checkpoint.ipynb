# %% [markdown]
# ## 00_readingInput.py
# ---
# 如何讀入資料

# %%
# %load 00_readingInput.py
import numpy as np
np.random.seed(1337)

''' Read input files '''
my_data = np.genfromtxt('pkgo_city66_class5_v1.csv', delimiter=',',skip_header=1)

''' The first column to the 199th column is used as input features '''
X_train = my_data[:,0:200]
X_train = X_train.astype('float32')

''' The 200-th column is the answer '''
y_train = my_data[:,200]
y_train = y_train.astype('int')

''' Convert to one-hot encoding '''
from keras.utils import np_utils
Y_train = np_utils.to_categorical(y_train,5)

''' Shuffle training data '''
from sklearn.utils import shuffle
X_train,Y_train = shuffle(X_train,Y_train,random_state=100)

print("numbers of data in training set: %g" % X_train.shape[0])
print("numbers of features: %g" % X_train.shape[1])
print("numbers of classes: %g" % Y_train.shape[1])
# Out:
# numbers of data in training set: 1836
# numbers of features: 200
# numbers of classes: 5

# %% [markdown]
# ## 00_firstmodel.py
# ---
# 隨便刻的第一個模型

# %%
# %load 00_firstModel.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile("00_readingInput.py")

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

# print 'Building a model whose loss function is categorical_crossentropy'
''' For categorical_crossentropy '''
model_ce = Sequential()
model_ce.add(Dense(128, input_dim=200))
model_ce.add(Activation('sigmoid'))
model_ce.add(Dense(256))
model_ce.add(Activation('sigmoid'))
model_ce.add(Dense(5))
model_ce.add(Activation('softmax'))

''' Set up the optimizer '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)

''' Compile model with specified loss and optimizer '''
model_ce.compile(loss='categorical_crossentropy',
				optimizer=sgd,
				metrics=['accuracy'])

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 30

'''Fit models and use validation_split=0.1 '''
history_ce = model_ce.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=1,
							shuffle=True,
                    		validation_split=0.1)

'''Access the loss and accuracy in every epoch'''
loss_ce	= history_ce.history.get('loss')
acc_ce 	= history_ce.history.get('acc')

''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_ce)), loss_ce,label='CE')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_ce)), acc_ce,label='CE')
plt.title('Accuracy')
plt.savefig('00_firstModel.png',dpi=300,format='png')
plt.close()
print('Result saved into 00_firstModel.png')
# Out:
# Using TensorFlow backend.
# Train on 1652 samples, validate on 184 samples
# Epoch 1/30
# 1652/1652 [==============================] - 2s - loss: 1.3802 - acc: 0.5024 - val_loss: 1.3445 - val_acc: 0.5163
# Epoch 2/30
# 1652/1652 [==============================] - 0s - loss: 1.3555 - acc: 0.5163 - val_loss: 1.3283 - val_acc: 0.5163
# Epoch 3/30
# 1652/1652 [==============================] - 0s - loss: 1.3526 - acc: 0.5163 - val_loss: 1.3725 - val_acc: 0.5163
# Epoch 4/30
# 1652/1652 [==============================] - 0s - loss: 1.3520 - acc: 0.5163 - val_loss: 1.3508 - val_acc: 0.5163
# Epoch 5/30
# 1652/1652 [==============================] - 0s - loss: 1.3442 - acc: 0.5163 - val_loss: 1.3204 - val_acc: 0.5163
# Epoch 6/30
# 1652/1652 [==============================] - 0s - loss: 1.3420 - acc: 0.5163 - val_loss: 1.3109 - val_acc: 0.5163
# Epoch 7/30
# 1652/1652 [==============================] - 0s - loss: 1.3375 - acc: 0.5163 - val_loss: 1.3066 - val_acc: 0.5163
# Epoch 8/30
# 1652/1652 [==============================] - 0s - loss: 1.3341 - acc: 0.5163 - val_loss: 1.3039 - val_acc: 0.5163
# Epoch 9/30
# 1652/1652 [==============================] - 0s - loss: 1.3265 - acc: 0.5163 - val_loss: 1.2976 - val_acc: 0.5163
# Epoch 10/30
# 1652/1652 [==============================] - 0s - loss: 1.3208 - acc: 0.5163 - val_loss: 1.3026 - val_acc: 0.5163
# Epoch 11/30
# 1652/1652 [==============================] - 0s - loss: 1.3163 - acc: 0.5169 - val_loss: 1.3536 - val_acc: 0.5761
# Epoch 12/30
# 1652/1652 [==============================] - 0s - loss: 1.3118 - acc: 0.5182 - val_loss: 1.2808 - val_acc: 0.5163
# Epoch 13/30
# 1652/1652 [==============================] - 0s - loss: 1.3099 - acc: 0.5163 - val_loss: 1.2753 - val_acc: 0.5163
# Epoch 14/30
# 1652/1652 [==============================] - 0s - loss: 1.2988 - acc: 0.5188 - val_loss: 1.2735 - val_acc: 0.5163
# Epoch 15/30
# 1652/1652 [==============================] - 0s - loss: 1.2902 - acc: 0.5248 - val_loss: 1.2576 - val_acc: 0.5380
# Epoch 16/30
# 1652/1652 [==============================] - 0s - loss: 1.2877 - acc: 0.5291 - val_loss: 1.2398 - val_acc: 0.5272
# Epoch 17/30
# 1652/1652 [==============================] - 0s - loss: 1.2764 - acc: 0.5327 - val_loss: 1.2437 - val_acc: 0.5163
# Epoch 18/30
# 1652/1652 [==============================] - 0s - loss: 1.2731 - acc: 0.5393 - val_loss: 1.2188 - val_acc: 0.5652
# Epoch 19/30
# 1652/1652 [==============================] - 0s - loss: 1.2649 - acc: 0.5575 - val_loss: 1.2368 - val_acc: 0.6304
# Epoch 20/30
# 1652/1652 [==============================] - 0s - loss: 1.2622 - acc: 0.5557 - val_loss: 1.2243 - val_acc: 0.5326
# Epoch 21/30
# 1652/1652 [==============================] - 0s - loss: 1.2550 - acc: 0.5678 - val_loss: 1.2288 - val_acc: 0.5380
# Epoch 22/30
# 1652/1652 [==============================] - 0s - loss: 1.2486 - acc: 0.5636 - val_loss: 1.1995 - val_acc: 0.5707
# Epoch 23/30
# 1652/1652 [==============================] - 0s - loss: 1.2459 - acc: 0.5720 - val_loss: 1.2037 - val_acc: 0.5761
# Epoch 24/30
# 1652/1652 [==============================] - 0s - loss: 1.2354 - acc: 0.5805 - val_loss: 1.2268 - val_acc: 0.5489
# Epoch 25/30
# 1652/1652 [==============================] - 0s - loss: 1.2321 - acc: 0.5720 - val_loss: 1.1767 - val_acc: 0.5978
# Epoch 26/30
# 1652/1652 [==============================] - 0s - loss: 1.2277 - acc: 0.5775 - val_loss: 1.2157 - val_acc: 0.6250
# Epoch 27/30
# 1652/1652 [==============================] - 0s - loss: 1.2254 - acc: 0.5787 - val_loss: 1.1852 - val_acc: 0.5870
# Epoch 28/30
# 1652/1652 [==============================] - 0s - loss: 1.2220 - acc: 0.5787 - val_loss: 1.1500 - val_acc: 0.6304
# Epoch 29/30
# 1652/1652 [==============================] - 0s - loss: 1.2187 - acc: 0.5841 - val_loss: 1.1702 - val_acc: 0.6304
# Epoch 30/30
# 1652/1652 [==============================] - 0s - loss: 1.2143 - acc: 0.5769 - val_loss: 1.1598 - val_acc: 0.6196
# Result saved into 00_firstModel.png

# %%
# %matplotlib inline
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_ce)), loss_ce,label='CE')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_ce)), acc_ce,label='CE')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# ## 01_lossFunctionSelection
# ---
# 比較兩種 loss function 在分類問題上的差別
# * Mean square error
# * categorical crossentropy

# %%
# %load 01_lossFuncSelection.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

# print 'Building a model whose loss function is categorical_crossentropy'
''' For categorical_crossentropy '''
model_ce = Sequential()
model_ce.add(Dense(128, input_dim=200))
model_ce.add(Activation('sigmoid'))
model_ce.add(Dense(256))
model_ce.add(Activation('sigmoid'))
model_ce.add(Dense(5))
model_ce.add(Activation('softmax'))

# print 'Building a model whose loss function is mean_squared_error'
''' For mean_squared_error '''
model_mse = Sequential()
model_mse.add(Dense(128, input_dim=200))
model_mse.add(Activation('sigmoid'))
model_mse.add(Dense(256))
model_mse.add(Activation('sigmoid'))
model_mse.add(Dense(5))
model_mse.add(Activation('softmax'))

''' Set up the optimizer '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)

''' Compile model with specified loss and optimizer '''
model_ce.compile(loss='categorical_crossentropy',
				optimizer=sgd,
				metrics=['accuracy'])

model_mse.compile(loss= 'mean_squared_error',
              optimizer=sgd,
              metrics=['accuracy'])

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 30

'''Fit models and use validation_split=0.1 '''
history_ce = model_ce.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

history_mse = model_mse.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

'''Access the loss and accuracy in every epoch'''
loss_ce	= history_ce.history.get('loss')
acc_ce 	= history_ce.history.get('acc')
loss_mse= history_mse.history.get('loss')
acc_mse = history_mse.history.get('acc')

''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_ce)), loss_ce,label='CE')
plt.plot(range(len(loss_mse)), loss_mse,label='MSE')
plt.title('Loss')
plt.subplot(122)
plt.plot(range(len(acc_ce)), acc_ce,label='CE')
plt.plot(range(len(acc_mse)), acc_mse,label='MSE')
plt.title('Accuracy')
plt.legend(loc='lower right')
plt.savefig('01_lossFuncSelection.png',dpi=300,format='png')
plt.close()
print('Result saved into 01_lossFuncSelection.png')
# Out:
# Train on 1652 samples, validate on 184 samples
# Epoch 1/30
# 0s - loss: 1.3832 - acc: 0.5024 - val_loss: 1.3342 - val_acc: 0.5163
# Epoch 2/30
# 0s - loss: 1.3559 - acc: 0.5163 - val_loss: 1.3229 - val_acc: 0.5163
# Epoch 3/30
# 0s - loss: 1.3525 - acc: 0.5163 - val_loss: 1.3321 - val_acc: 0.5163
# Epoch 4/30
# 0s - loss: 1.3477 - acc: 0.5163 - val_loss: 1.3303 - val_acc: 0.5163
# Epoch 5/30
# 0s - loss: 1.3416 - acc: 0.5163 - val_loss: 1.3608 - val_acc: 0.5163
# Epoch 6/30
# 0s - loss: 1.3411 - acc: 0.5163 - val_loss: 1.3262 - val_acc: 0.5163
# Epoch 7/30
# 0s - loss: 1.3358 - acc: 0.5163 - val_loss: 1.3548 - val_acc: 0.5163
# Epoch 8/30
# 0s - loss: 1.3352 - acc: 0.5163 - val_loss: 1.3211 - val_acc: 0.5163
# Epoch 9/30
# 0s - loss: 1.3227 - acc: 0.5163 - val_loss: 1.3243 - val_acc: 0.5163
# Epoch 10/30
# 0s - loss: 1.3223 - acc: 0.5163 - val_loss: 1.2865 - val_acc: 0.5163
# Epoch 11/30
# 0s - loss: 1.3144 - acc: 0.5163 - val_loss: 1.3061 - val_acc: 0.5707
# Epoch 12/30
# 0s - loss: 1.3100 - acc: 0.5176 - val_loss: 1.3167 - val_acc: 0.5163
# Epoch 13/30
# 0s - loss: 1.3031 - acc: 0.5169 - val_loss: 1.2704 - val_acc: 0.5163
# Epoch 14/30
# 0s - loss: 1.2962 - acc: 0.5176 - val_loss: 1.2692 - val_acc: 0.5163
# Epoch 15/30
# 0s - loss: 1.2894 - acc: 0.5230 - val_loss: 1.2904 - val_acc: 0.5272
# Epoch 16/30
# 0s - loss: 1.2842 - acc: 0.5291 - val_loss: 1.2702 - val_acc: 0.5163
# Epoch 17/30
# 0s - loss: 1.2759 - acc: 0.5297 - val_loss: 1.2249 - val_acc: 0.5652
# Epoch 18/30
# 0s - loss: 1.2703 - acc: 0.5496 - val_loss: 1.2263 - val_acc: 0.5761
# Epoch 19/30
# 0s - loss: 1.2642 - acc: 0.5539 - val_loss: 1.2084 - val_acc: 0.6304
# Epoch 20/30
# 0s - loss: 1.2557 - acc: 0.5678 - val_loss: 1.2282 - val_acc: 0.5489
# Epoch 21/30
# 0s - loss: 1.2534 - acc: 0.5696 - val_loss: 1.2363 - val_acc: 0.6304
# Epoch 22/30
# 0s - loss: 1.2472 - acc: 0.5702 - val_loss: 1.1791 - val_acc: 0.6250
# Epoch 23/30
# 0s - loss: 1.2435 - acc: 0.5684 - val_loss: 1.2463 - val_acc: 0.5326
# Epoch 24/30
# 0s - loss: 1.2411 - acc: 0.5745 - val_loss: 1.2437 - val_acc: 0.5435
# Epoch 25/30
# 0s - loss: 1.2338 - acc: 0.5732 - val_loss: 1.1770 - val_acc: 0.6196
# Epoch 26/30
# 0s - loss: 1.2301 - acc: 0.5799 - val_loss: 1.1844 - val_acc: 0.5815
# Epoch 27/30
# 0s - loss: 1.2257 - acc: 0.5811 - val_loss: 1.1835 - val_acc: 0.5761
# Epoch 28/30
# 0s - loss: 1.2219 - acc: 0.5775 - val_loss: 1.1650 - val_acc: 0.6304
# Epoch 29/30
# 0s - loss: 1.2205 - acc: 0.5799 - val_loss: 1.1513 - val_acc: 0.6304
# Epoch 30/30
# 0s - loss: 1.2181 - acc: 0.5823 - val_loss: 1.1582 - val_acc: 0.6250
# Train on 1652 samples, validate on 184 samples
# Epoch 1/30
# 0s - loss: 0.1495 - acc: 0.4116 - val_loss: 0.1353 - val_acc: 0.5163
# Epoch 2/30
# 0s - loss: 0.1362 - acc: 0.5163 - val_loss: 0.1347 - val_acc: 0.5163
# Epoch 3/30
# 0s - loss: 0.1356 - acc: 0.5163 - val_loss: 0.1344 - val_acc: 0.5163
# Epoch 4/30
# 0s - loss: 0.1352 - acc: 0.5163 - val_loss: 0.1341 - val_acc: 0.5163
# Epoch 5/30
# 0s - loss: 0.1348 - acc: 0.5163 - val_loss: 0.1339 - val_acc: 0.5163
# Epoch 6/30
# 0s - loss: 0.1346 - acc: 0.5163 - val_loss: 0.1339 - val_acc: 0.5163
# Epoch 7/30
# 0s - loss: 0.1345 - acc: 0.5163 - val_loss: 0.1338 - val_acc: 0.5163
# Epoch 8/30
# 0s - loss: 0.1343 - acc: 0.5163 - val_loss: 0.1339 - val_acc: 0.5163
# Epoch 9/30
# 0s - loss: 0.1342 - acc: 0.5163 - val_loss: 0.1338 - val_acc: 0.5163
# Epoch 10/30
# 0s - loss: 0.1342 - acc: 0.5163 - val_loss: 0.1337 - val_acc: 0.5163
# Epoch 11/30
# 0s - loss: 0.1340 - acc: 0.5163 - val_loss: 0.1336 - val_acc: 0.5163
# Epoch 12/30
# 0s - loss: 0.1340 - acc: 0.5163 - val_loss: 0.1336 - val_acc: 0.5163
# Epoch 13/30
# 0s - loss: 0.1340 - acc: 0.5163 - val_loss: 0.1335 - val_acc: 0.5163
# Epoch 14/30
# 0s - loss: 0.1338 - acc: 0.5163 - val_loss: 0.1334 - val_acc: 0.5163
# Epoch 15/30
# 0s - loss: 0.1338 - acc: 0.5163 - val_loss: 0.1333 - val_acc: 0.5163
# Epoch 16/30
# 0s - loss: 0.1337 - acc: 0.5163 - val_loss: 0.1333 - val_acc: 0.5163
# Epoch 17/30
# 0s - loss: 0.1337 - acc: 0.5163 - val_loss: 0.1331 - val_acc: 0.5163
# Epoch 18/30
# 0s - loss: 0.1337 - acc: 0.5163 - val_loss: 0.1331 - val_acc: 0.5163
# Epoch 19/30
# 0s - loss: 0.1336 - acc: 0.5163 - val_loss: 0.1330 - val_acc: 0.5163
# Epoch 20/30
# 0s - loss: 0.1334 - acc: 0.5163 - val_loss: 0.1329 - val_acc: 0.5163
# Epoch 21/30
# 0s - loss: 0.1335 - acc: 0.5163 - val_loss: 0.1329 - val_acc: 0.5163
# Epoch 22/30
# 0s - loss: 0.1334 - acc: 0.5163 - val_loss: 0.1329 - val_acc: 0.5163
# Epoch 23/30
# 0s - loss: 0.1334 - acc: 0.5163 - val_loss: 0.1327 - val_acc: 0.5163
# Epoch 24/30
# 0s - loss: 0.1333 - acc: 0.5163 - val_loss: 0.1327 - val_acc: 0.5163
# Epoch 25/30
# 0s - loss: 0.1333 - acc: 0.5163 - val_loss: 0.1327 - val_acc: 0.5163
# Epoch 26/30
# 0s - loss: 0.1332 - acc: 0.5163 - val_loss: 0.1326 - val_acc: 0.5163
# Epoch 27/30
# 0s - loss: 0.1332 - acc: 0.5163 - val_loss: 0.1324 - val_acc: 0.5163
# Epoch 28/30
# 0s - loss: 0.1331 - acc: 0.5163 - val_loss: 0.1324 - val_acc: 0.5163
# Epoch 29/30
# 0s - loss: 0.1331 - acc: 0.5163 - val_loss: 0.1324 - val_acc: 0.5163
# Epoch 30/30
# 0s - loss: 0.1331 - acc: 0.5163 - val_loss: 0.1323 - val_acc: 0.5163
# Result saved into 01_lossFuncSelection.png

# %%
# %matplotlib inline
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_ce)), loss_ce,label='CE')
plt.plot(range(len(loss_mse)), loss_mse,label='MSE')
plt.title('Loss')
plt.subplot(122)
plt.plot(range(len(acc_ce)), acc_ce,label='CE')
plt.plot(range(len(acc_mse)), acc_mse,label='MSE')
plt.title('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 02_learningRate
# ---
# 比較三種 learning rate (0.1, 0.01, 0.001) under SGD optimizer

# %%
# %load 02_learningRateSelection.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 30

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

print('Building model using SGD(lr=0.1)')
''' 1. Model using large learning rate '''
model_large = Sequential()
model_large.add(Dense(128, input_dim=200))
model_large.add(Activation('sigmoid'))
model_large.add(Dense(256))
model_large.add(Activation('sigmoid'))
model_large.add(Dense(5))
model_large.add(Activation('softmax'))

''' set the learning rate of SGD optimizer to 0.1 '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd1 = SGD(lr=0.1,momentum=0.0,decay=0.0,nesterov=False)

model_large.compile(loss= 'categorical_crossentropy',
              optimizer=sgd1,
              metrics=['accuracy'])

history_large = model_large.fit(X_train, Y_train,
								batch_size=batch_size,
								epochs=epochs,
								verbose=0,
								shuffle=True,
                    			validation_split=0.1)

loss_large = history_large.history.get('loss')
acc_large = history_large.history.get('acc')

print('Building model using SGD(lr=0.01)')
''' 2. Model using median learning rate '''
model_median = Sequential()
model_median.add(Dense(128, input_dim=200))
model_median.add(Activation('sigmoid'))
model_median.add(Dense(256))
model_median.add(Activation('sigmoid'))
model_median.add(Dense(5))
model_median.add(Activation('softmax'))

''' set the learning rate of SGD optimizer to 0.01 '''
sgd2 = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)

model_median.compile(loss= 'categorical_crossentropy',
              optimizer=sgd2,
              metrics=['accuracy'])

history_median = model_median.fit(X_train, Y_train,
						batch_size=batch_size,
						epochs=epochs,
						verbose=0,
						shuffle=True,
                    	validation_split=0.1)

loss_median = history_median.history.get('loss')
acc_median = history_median.history.get('acc')

print('Building model using SGD(lr=0.001)')
''' 3. Model using small learning rate '''
model_small = Sequential()
model_small.add(Dense(128, input_dim=200))
model_small.add(Activation('sigmoid'))
model_small.add(Dense(256))
model_small.add(Activation('sigmoid'))
model_small.add(Dense(5))
model_small.add(Activation('softmax'))

''' set the learning rate of SGD optimizer to 0.001 '''
sgd3 = SGD(lr=0.001,momentum=0.0,decay=0.0,nesterov=False)

model_small.compile(loss= 'categorical_crossentropy',
              optimizer=sgd3,
              metrics=['accuracy'])

history_small = model_small.fit(X_train, Y_train,
						batch_size=batch_size,
						epochs=epochs,
						verbose=0,
						shuffle=True,
                    	validation_split=0.1)

loss_small = history_small.history.get('loss')
acc_small = history_small.history.get('acc')

# %%
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_large)), loss_large,label='lr=0.1')
plt.plot(range(len(loss_median)), loss_median,label='lr=0.01')
plt.plot(range(len(loss_small)), loss_small,label='lr=0.001')
plt.title('Loss')
plt.subplot(122)
plt.plot(range(len(acc_large)), acc_large,label='lr=0.1')
plt.plot(range(len(acc_median)), acc_median,label='lr=0.01')
plt.plot(range(len(acc_small)), acc_small,label='lr=0.001')
plt.title('Accuracy')
plt.legend(loc='lower right')
#plt.savefig('02_learningRateSelection.png',dpi=300,format='png')
#plt.close()
plt.show()
print('Result saved into 02_learningRateSelection.png')
# Out:
# Result saved into 02_learningRateSelection.png

# %% [markdown]
# ## 03_activationFuncSelection
# ---
# 比較不同的 activation function 對 performance 的影響

# %%
# %load 03_activationFuncSelection.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 30

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

print('Building model using relu as activation function')
''' Use relu as our activation function '''
model_sp = Sequential()
model_sp.add(Dense(128, input_dim=200))
model_sp.add(Activation('relu'))
model_sp.add(Dense(256))
model_sp.add(Activation('relu'))
model_sp.add(Dense(5))
model_sp.add(Activation('softmax'))

''' Use SGD(lr=0.01) as the optimizer  '''
''' lr set to 0.01 according to 02_learningRateSelection.py '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)

model_sp.compile(loss= 'categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

history_sp = model_sp.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)

loss_sp = history_sp.history.get('loss')
acc_sp = history_sp.history.get('acc')

print('Building model using sigmoid as activation function')
# reference
model_bm = Sequential()
model_bm.add(Dense(128, input_dim=200))
model_bm.add(Activation('sigmoid'))
model_bm.add(Dense(256))
model_bm.add(Activation('sigmoid'))
model_bm.add(Dense(5))
model_bm.add(Activation('softmax'))
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)
model_bm.compile(loss='categorical_crossentropy',
				optimizer=sgd,
				metrics=['accuracy'])
history_bm = model_bm.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
loss_bm	= history_bm.history.get('loss')
acc_bm 	= history_bm.history.get('acc')

print('Building model using softmax as activation function (???)')
# reference
model_sm = Sequential()
model_sm.add(Dense(128, input_dim=200))
model_sm.add(Activation('softmax'))
model_sm.add(Dense(256))
model_sm.add(Activation('softmax'))
model_sm.add(Dense(5))
model_sm.add(Activation('softmax'))
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
sgd = SGD(lr=0.01,momentum=0.0,decay=0.0,nesterov=False)
model_sm.compile(loss='categorical_crossentropy',
				optimizer=sgd,
				metrics=['accuracy'])
history_sm = model_sm.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
loss_sm	= history_sm.history.get('loss')
acc_sm 	= history_sm.history.get('acc')
# Out:
# Building model using relu as activation function
# Building model using sigmoid as activation function
# Building model using sigmoid as activation function

# %%
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_sp)),loss_sp,label='relu')
plt.plot(range(len(loss_bm)),loss_bm,label='Sigmoid')
plt.plot(range(len(loss_sm)),loss_sm,label='Softmax')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_sp)),acc_sp,label='relu')
plt.plot(range(len(acc_bm)),acc_bm,label='Sigmoid')
plt.plot(range(len(acc_sm)),acc_sm,label='Softmax')
plt.title('Accuracy')
#plt.savefig('03_activationFuncSelection.png',dpi=300,format='png')
#plt.close()
#print('Result saved into 03_activationFuncSelection.png')
plt.show()

# %% [markdown]
# ## 04_optimizer
# ---
# 比較不同 optimizer 的影響

# %%
# %load 04_optimizerSelection.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 30

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

print('Building a model whose optimizer="Adam", activation function=relu')
model_adam = Sequential()
model_adam.add(Dense(128, input_dim=200))
model_adam.add(Activation('relu'))
model_adam.add(Dense(256))
model_adam.add(Activation('relu'))
model_adam.add(Dense(5))
model_adam.add(Activation('softmax'))

''' Setting optimizer as Adam '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_adam = model_adam.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)

loss_adam= history_adam.history.get('loss')
acc_adam = history_adam.history.get('acc')

print('Building a model whose optimizer="SGD", activation function=relu')
model_sgd = Sequential()
model_sgd.add(Dense(128, input_dim=200))
model_sgd.add(Activation('relu'))
model_sgd.add(Dense(256))
model_sgd.add(Activation('relu'))
model_sgd.add(Dense(5))
model_sgd.add(Activation('softmax'))

''' Setting optimizer as SGD '''
model_sgd.compile(loss='categorical_crossentropy',
				optimizer='SGD',
				metrics=['accuracy'])

history_sgd = model_sgd.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)

loss_sgd= history_sgd.history.get('loss')
acc_sgd = history_sgd.history.get('acc')
# Out:
# Building a model whose optimizer="Adam", activation function=relu
# Building a model whose optimizer="SGD", activation function=relu

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_adam)), loss_adam,label='Adam')
plt.plot(range(len(loss_sgd)), loss_sgd,label='SGD')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_adam)), acc_adam,label='Adam')
plt.plot(range(len(acc_sgd)), acc_sgd,label='SGD')
plt.title('Accuracy')
#plt.savefig('04_optimizerSelection.png',dpi=300,format='png')
#plt.close()
#print('Result saved into 04_optimizerSelection.png')
plt.show()

# %% [markdown]
# ## 05_overfitting Check
# ---

# %%
# %load 05_overfittingCheck.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 50

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Activation

print('Building a model whose optimizer="Adam", activation function=relu')
model_adam = Sequential()
model_adam.add(Dense(128, input_dim=200))
model_adam.add(Activation('relu'))
model_adam.add(Dense(256))
model_adam.add(Activation('relu'))
model_adam.add(Dense(5))
model_adam.add(Activation('softmax'))

''' Setting optimizer as Adam '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_adam = model_adam.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)

loss_adam= history_adam.history.get('loss')
acc_adam = history_adam.history.get('acc')

''' Access the performance on validation data '''
val_loss_adam = history_adam.history.get('val_loss')
val_acc_adam = history_adam.history.get('val_acc')

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_adam)), loss_adam,label='Training')
plt.plot(range(len(val_loss_adam)), val_loss_adam,label='Validation')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_adam)), acc_adam,label='Training')
plt.plot(range(len(val_acc_adam)), val_acc_adam,label='Validation')
plt.title('Accuracy')
#plt.savefig('05_overfittingCheck.png',dpi=300,format='png')
#plt.close()
#print('Result saved into 05_overfittingCheck.png')

plt.show()

# %% [markdown]
# ## 06_regularizers
# ---
# 對付 overfit 的方法 - 1 <br>
# 比較不同的 regulizers

# %%
# %load 06_regularizerl1l2.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' Import l1,l2 (regularizer) '''
from keras.regularizers import l1,l2, l1_l2

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 50

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

def build_model_with_regulizers(l1n = 0., l2n = 0.):
    print('Building a model with regularizer L1: %g, L2: %g' % (l1n, l2n))
    model = Sequential()
    model.add(Dense(128, input_dim=200, kernel_regularizer=l1_l2(l1 = l1n, l2 = l2n) ))
    model.add(Activation('relu'))
    model.add(Dense(256, kernel_regularizer=l1_l2(l1 = l1n, l2 = l2n) ))
    model.add(Activation('relu'))
    model.add(Dense(5, kernel_regularizer=l1_l2(l1 = l1n, l2 = l2n)))
    model.add(Activation('softmax'))

    return model

''' Setting optimizer as Adam '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
model_l2 = build_model_with_regulizers(l1n = 0, l2n = 0.005)
model_l2.compile(loss= 'categorical_crossentropy',
              	optimizer='Adam',
              	metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_l2 = model_l2.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
loss_l2 = history_l2.history.get('loss')
acc_l2 = history_l2.history.get('acc')
val_loss_l2 = history_l2.history.get('val_loss')
val_acc_l2 = history_l2.history.get('val_acc')


model_l2a = build_model_with_regulizers(l1n = 0, l2n = 0.5)
model_l2a.compile(loss= 'categorical_crossentropy',
              	optimizer='Adam',
              	metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_l2a = model_l2a.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
loss_l2a = history_l2a.history.get('loss')
acc_l2a = history_l2a.history.get('acc')
val_loss_l2a = history_l2a.history.get('val_loss')
val_acc_l2a = history_l2a.history.get('val_acc')

##
model_l1 = build_model_with_regulizers(l1n = 0.005, l2n = 0.)
model_l1.compile(loss= 'categorical_crossentropy',
              	optimizer='Adam',
              	metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_l1 = model_l1.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
loss_l1 = history_l1.history.get('loss')
acc_l1 = history_l1.history.get('acc')
val_loss_l1 = history_l1.history.get('val_loss')
val_acc_l1 = history_l1.history.get('val_acc')

# reference
print('model without regularizers')
model_adam = build_model_with_regulizers(l1n = 0., l2n = 0.)
''' Setting optimizer as Adam '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_adam = model_adam.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=0,
							shuffle=True,
                    		validation_split=0.1)
''' Access the performance on validation data '''
loss_adam = history_adam.history.get('loss')
acc_adam = history_adam.history.get('acc')
val_loss_adam = history_adam.history.get('val_loss')
val_acc_adam = history_adam.history.get('val_acc')
# Out:
# Building a model with regularizer L1: 0, L2: 0.005
# Building a model with regularizer L1: 0, L2: 0.5
# Building a model with regularizer L1: 0.005, L2: 0
# model without regularizers
# Building a model with regularizer L1: 0, L2: 0

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(221)
plt.plot(range(len(loss_adam)), loss_adam,label='Training')
plt.plot(range(len(val_loss_adam)), val_loss_adam,label='Validation')
plt.title('Loss - Original')
plt.legend(loc='upper left')
plt.subplot(222)
plt.plot(range(len(loss_l2)), loss_l2,label='Training')
plt.plot(range(len(val_loss_l2)), val_loss_l2,label='Validation')
plt.title('Loss - With L2 Regularizer: 0.005')
plt.subplot(223)
plt.plot(range(len(loss_l2a)), loss_l2a,label='Training')
plt.plot(range(len(val_loss_l2a)), val_loss_l2a,label='Validation')
plt.title('Loss - With L2 Regularizer: 0.5')
plt.subplot(224)
plt.plot(range(len(loss_l1)), loss_l1,label='Training')
plt.plot(range(len(val_loss_l1)), val_loss_l1,label='Validation')
plt.title('Loss - With L1 Regularizer: 0.005')

#plt.savefig('06_regularizer.png',dpi=300,format='png')
#plt.close()
#print('Result saved into 06_regularizer.png')
plt.tight_layout()
plt.show()

plt.figure(0)
plt.subplot(121)
plt.plot(range(len(acc_adam)), acc_adam, label = 'without regularizer')
plt.plot(range(len(acc_adam)), acc_l1, label = 'L1 regularizer: 0.005')
plt.plot(range(len(acc_adam)), acc_l2, label = 'L2 regularizer: 0.005')
plt.plot(range(len(acc_adam)), acc_l2a, label = 'L2 regularizer: 0.5')
plt.legend(fontsize = 8, loc = 'lower right')
plt.subplot(122)
plt.plot(range(len(val_acc_adam)), val_acc_adam, label = 'without regularizer')
plt.plot(range(len(val_acc_adam)), val_acc_l1, label = 'L1 regularizer: 0.005')
plt.plot(range(len(val_acc_adam)), val_acc_l2, label = 'L2 regularizer: 0.005')
plt.plot(range(len(val_acc_adam)), val_acc_l2a, label = 'L2 regularizer: 0.5')
plt.legend(fontsize = 8, loc = 'lower right')
plt.show()

# %% [markdown]
# ## 07_EarlyStop
# ---
# 對付 overfit 的方法 - 2

# %%
# %load 07_earlyStopping.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' EarlyStopping '''
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 3)

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 50

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

print('Building current best model with EarlyStopping')
model_adam = Sequential()
model_adam.add(Dense(128, input_dim=200))
model_adam.add(Activation('relu'))
model_adam.add(Dense(256))
model_adam.add(Activation('relu'))
model_adam.add(Dense(5))
model_adam.add(Activation('softmax'))

''' Setting optimizer as Adam '''
from keras.optimizers import SGD, Adam, RMSprop, Adagrad
model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])

'''Fit models and use validation_split=0.1 '''
history_adam = model_adam.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1,
                    		callbacks=[early_stopping])

loss_adam = history_adam.history.get('loss')
acc_adam = history_adam.history.get('acc')
val_loss_adam = history_adam.history.get('val_loss')
val_acc_adam = history_adam.history.get('val_acc')
# Out:
# Building current best model with EarlyStopping
# Train on 1652 samples, validate on 184 samples
# Epoch 1/50
# 1652/1652 [==============================] - 1s - loss: 1.8524 - acc: 0.4607 - val_loss: 1.1708 - val_acc: 0.6304
# Epoch 2/50
# 1652/1652 [==============================] - 0s - loss: 1.2120 - acc: 0.5914 - val_loss: 1.1523 - val_acc: 0.5870
# Epoch 3/50
# 1652/1652 [==============================] - 0s - loss: 1.0792 - acc: 0.6053 - val_loss: 0.9355 - val_acc: 0.6739
# Epoch 4/50
# 1652/1652 [==============================] - 0s - loss: 1.0429 - acc: 0.6392 - val_loss: 0.8998 - val_acc: 0.6522
# Epoch 5/50
# 1652/1652 [==============================] - 0s - loss: 1.0053 - acc: 0.6453 - val_loss: 0.8774 - val_acc: 0.6630
# Epoch 6/50
# 1652/1652 [==============================] - 0s - loss: 0.9382 - acc: 0.6774 - val_loss: 0.8836 - val_acc: 0.6793
# Epoch 7/50
# 1652/1652 [==============================] - 0s - loss: 0.9553 - acc: 0.6598 - val_loss: 0.9087 - val_acc: 0.6739
# Epoch 8/50
# 1652/1652 [==============================] - 0s - loss: 0.8926 - acc: 0.6973 - val_loss: 0.8214 - val_acc: 0.7065
# Epoch 9/50
# 1652/1652 [==============================] - 0s - loss: 0.9175 - acc: 0.6816 - val_loss: 0.7692 - val_acc: 0.7065
# Epoch 10/50
# 1652/1652 [==============================] - 0s - loss: 0.8374 - acc: 0.7052 - val_loss: 0.7870 - val_acc: 0.7011
# Epoch 11/50
# 1652/1652 [==============================] - 0s - loss: 0.8290 - acc: 0.7100 - val_loss: 0.8929 - val_acc: 0.6848
# Epoch 12/50
# 1652/1652 [==============================] - 0s - loss: 0.8222 - acc: 0.7240 - val_loss: 0.7294 - val_acc: 0.7446
# Epoch 13/50
# 1652/1652 [==============================] - 0s - loss: 0.7960 - acc: 0.7125 - val_loss: 0.8344 - val_acc: 0.6902
# Epoch 14/50
# 1652/1652 [==============================] - 0s - loss: 0.7535 - acc: 0.7373 - val_loss: 0.8601 - val_acc: 0.6902
# Epoch 15/50
# 1652/1652 [==============================] - 0s - loss: 0.7493 - acc: 0.7464 - val_loss: 0.8674 - val_acc: 0.6848
# Epoch 16/50
# 1652/1652 [==============================] - 0s - loss: 0.7422 - acc: 0.7536 - val_loss: 0.7657 - val_acc: 0.7446

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
plt.figure(0)
plt.subplot(121)
plt.plot(range(len(loss_adam)), loss_adam,label='Training')
plt.plot(range(len(val_loss_adam)), val_loss_adam,label='Validation')
plt.title('Loss')
plt.legend(loc='upper left')
plt.subplot(122)
plt.plot(range(len(acc_adam)), acc_adam,label='Training')
plt.plot(range(len(val_acc_adam)), val_acc_adam,label='Validation')
plt.title('Accuracy')

plt.show()
#plt.savefig('07_earlystopping.png',dpi=300,format='png')
#plt.close()
#print('Result saved into 07_earlystopping.png')

# %% [markdown]
# ## 08_dropout
# ---
# 對付 overfit 的方法 - 3 <br>
# 比較不同比例的 dropout 對 loss 和 accuracy 的影響

# %%
# %load 08_dropout.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 16
epochs = 100

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam, RMSprop, Adagrad

def create_model_withDrp(ratio_dropout):
	
	print('Building current best model with Dropout = %g' % ratio_dropout)
	model_adam = Sequential()
	model_adam.add(Dense(128, input_dim=200))
	model_adam.add(Activation('relu'))
	model_adam.add(Dropout(ratio_dropout))
	model_adam.add(Dense(256))
	model_adam.add(Activation('relu'))
	model_adam.add(Dropout(ratio_dropout))
	model_adam.add(Dense(5))
	model_adam.add(Activation('softmax'))
	##
	model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])

	return model_adam

model_adam_drp10 = create_model_withDrp(0.1)
model_adam_drp20 = create_model_withDrp(0.2)
model_adam_drp40 = create_model_withDrp(0.4)

'''Fit models and use validation_split=0.1 '''
history_adam_drp10 = model_adam_drp10.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

history_adam_drp20 = model_adam_drp20.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

history_adam_drp40 = model_adam_drp40.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

def get_result(history_model):
	train_loss = history_model.history.get('loss')
	train_acc = history_model.history.get('acc')
	valid_loss = history_model.history.get('val_loss')
	valid_acc = history_model.history.get('val_acc')
	return train_loss, train_acc, valid_loss, valid_acc

loss_adam_drp10, acc_adam_drp10, val_loss_adam_drp10, val_acc_adam_drp10 = get_result(history_adam_drp10)
loss_adam_drp20, acc_adam_drp20, val_loss_adam_drp20, val_acc_adam_drp20 = get_result(history_adam_drp20)
loss_adam_drp40, acc_adam_drp40, val_loss_adam_drp40, val_acc_adam_drp40 = get_result(history_adam_drp40)
# Out:
# Building current best model with Dropout = 0.1
# Building current best model with Dropout = 0.2
# Building current best model with Dropout = 0.4
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 1s - loss: 2.1878 - acc: 0.4219 - val_loss: 1.1864 - val_acc: 0.5978
# Epoch 2/100
# 0s - loss: 1.3548 - acc: 0.5200 - val_loss: 1.1318 - val_acc: 0.5924
# Epoch 3/100
# 0s - loss: 1.1763 - acc: 0.5751 - val_loss: 1.0109 - val_acc: 0.6304
# Epoch 4/100
# 0s - loss: 1.1469 - acc: 0.5926 - val_loss: 0.9792 - val_acc: 0.6848
# Epoch 5/100
# 0s - loss: 1.0526 - acc: 0.6084 - val_loss: 0.8984 - val_acc: 0.6793
# Epoch 6/100
# 0s - loss: 1.0323 - acc: 0.6326 - val_loss: 0.8981 - val_acc: 0.6902
# Epoch 7/100
# 0s - loss: 0.9790 - acc: 0.6507 - val_loss: 0.8801 - val_acc: 0.7065
# Epoch 8/100
# 0s - loss: 0.9468 - acc: 0.6665 - val_loss: 0.8397 - val_acc: 0.6793
# Epoch 9/100
# 0s - loss: 0.9129 - acc: 0.6731 - val_loss: 0.8431 - val_acc: 0.7228
# Epoch 10/100
# 0s - loss: 0.8888 - acc: 0.6834 - val_loss: 0.8206 - val_acc: 0.6957
# Epoch 11/100
# 0s - loss: 0.8744 - acc: 0.6937 - val_loss: 0.8294 - val_acc: 0.7228
# Epoch 12/100
# 0s - loss: 0.8463 - acc: 0.6955 - val_loss: 0.8145 - val_acc: 0.6957
# Epoch 13/100
# 0s - loss: 0.8244 - acc: 0.7137 - val_loss: 0.7898 - val_acc: 0.7174
# Epoch 14/100
# 0s - loss: 0.8247 - acc: 0.7100 - val_loss: 0.7870 - val_acc: 0.7065
# Epoch 15/100
# 0s - loss: 0.8189 - acc: 0.7052 - val_loss: 0.7653 - val_acc: 0.7174
# Epoch 16/100
# 0s - loss: 0.7974 - acc: 0.7070 - val_loss: 0.7546 - val_acc: 0.7446
# Epoch 17/100
# 0s - loss: 0.7847 - acc: 0.7094 - val_loss: 0.7883 - val_acc: 0.7391
# Epoch 18/100
# 0s - loss: 0.7493 - acc: 0.7240 - val_loss: 0.7453 - val_acc: 0.7283
# Epoch 19/100
# 0s - loss: 0.7549 - acc: 0.7288 - val_loss: 0.7466 - val_acc: 0.7446
# Epoch 20/100
# 0s - loss: 0.7364 - acc: 0.7379 - val_loss: 0.7630 - val_acc: 0.7391
# Epoch 21/100
# 0s - loss: 0.7113 - acc: 0.7470 - val_loss: 0.7615 - val_acc: 0.7120
# Epoch 22/100
# 0s - loss: 0.7088 - acc: 0.7567 - val_loss: 0.7356 - val_acc: 0.7609
# Epoch 23/100
# 0s - loss: 0.6956 - acc: 0.7500 - val_loss: 0.7637 - val_acc: 0.7337
# Epoch 24/100
# 0s - loss: 0.6614 - acc: 0.7621 - val_loss: 0.7372 - val_acc: 0.7609
# Epoch 25/100
# 0s - loss: 0.6715 - acc: 0.7657 - val_loss: 0.7477 - val_acc: 0.7337
# Epoch 26/100
# 0s - loss: 0.6546 - acc: 0.7663 - val_loss: 0.7352 - val_acc: 0.7446
# Epoch 27/100
# 0s - loss: 0.6385 - acc: 0.7760 - val_loss: 0.7253 - val_acc: 0.7391
# Epoch 28/100
# 0s - loss: 0.6320 - acc: 0.7694 - val_loss: 0.6990 - val_acc: 0.7717
# Epoch 29/100
# 0s - loss: 0.6185 - acc: 0.7833 - val_loss: 0.7415 - val_acc: 0.7554
# Epoch 30/100
# 0s - loss: 0.6006 - acc: 0.7881 - val_loss: 0.7305 - val_acc: 0.7337
# Epoch 31/100
# 0s - loss: 0.5865 - acc: 0.7863 - val_loss: 0.7606 - val_acc: 0.7337
# Epoch 32/100
# 0s - loss: 0.5960 - acc: 0.7881 - val_loss: 0.7580 - val_acc: 0.7391
# Epoch 33/100
# 0s - loss: 0.5680 - acc: 0.7966 - val_loss: 0.7246 - val_acc: 0.7554
# Epoch 34/100
# 0s - loss: 0.5937 - acc: 0.7881 - val_loss: 0.7954 - val_acc: 0.7228
# Epoch 35/100
# 0s - loss: 0.5411 - acc: 0.8099 - val_loss: 0.7441 - val_acc: 0.7337
# Epoch 36/100
# 0s - loss: 0.5252 - acc: 0.8178 - val_loss: 0.7505 - val_acc: 0.7120
# Epoch 37/100
# 0s - loss: 0.5291 - acc: 0.8142 - val_loss: 0.7424 - val_acc: 0.7228
# Epoch 38/100
# 0s - loss: 0.5011 - acc: 0.8178 - val_loss: 0.7379 - val_acc: 0.7337
# Epoch 39/100
# 0s - loss: 0.5084 - acc: 0.8136 - val_loss: 0.8108 - val_acc: 0.7174
# Epoch 40/100
# 0s - loss: 0.4919 - acc: 0.8269 - val_loss: 0.7342 - val_acc: 0.7500
# Epoch 41/100
# 0s - loss: 0.4884 - acc: 0.8202 - val_loss: 0.7818 - val_acc: 0.7500
# Epoch 42/100
# 0s - loss: 0.4754 - acc: 0.8263 - val_loss: 0.8405 - val_acc: 0.7228
# Epoch 43/100
# 0s - loss: 0.4920 - acc: 0.8263 - val_loss: 0.7918 - val_acc: 0.7228
# Epoch 44/100
# 0s - loss: 0.4561 - acc: 0.8341 - val_loss: 0.7451 - val_acc: 0.7446
# Epoch 45/100
# 0s - loss: 0.4632 - acc: 0.8341 - val_loss: 0.7439 - val_acc: 0.7609
# Epoch 46/100
# 0s - loss: 0.4365 - acc: 0.8456 - val_loss: 0.8179 - val_acc: 0.7663
# Epoch 47/100
# 0s - loss: 0.4142 - acc: 0.8456 - val_loss: 0.8184 - val_acc: 0.7337
# Epoch 48/100
# 0s - loss: 0.4028 - acc: 0.8517 - val_loss: 0.7797 - val_acc: 0.7717
# Epoch 49/100
# 0s - loss: 0.3890 - acc: 0.8535 - val_loss: 0.7866 - val_acc: 0.7609
# Epoch 50/100
# 0s - loss: 0.4061 - acc: 0.8481 - val_loss: 0.8480 - val_acc: 0.7065
# Epoch 51/100
# 0s - loss: 0.3985 - acc: 0.8475 - val_loss: 0.8714 - val_acc: 0.7120
# Epoch 52/100
# 0s - loss: 0.3933 - acc: 0.8535 - val_loss: 0.8541 - val_acc: 0.7120
# Epoch 53/100
# 0s - loss: 0.3747 - acc: 0.8596 - val_loss: 0.7472 - val_acc: 0.7717
# Epoch 54/100
# 0s - loss: 0.3555 - acc: 0.8729 - val_loss: 0.7706 - val_acc: 0.7554
# Epoch 55/100
# 0s - loss: 0.3635 - acc: 0.8620 - val_loss: 0.7642 - val_acc: 0.7989
# Epoch 56/100
# 0s - loss: 0.3549 - acc: 0.8614 - val_loss: 0.8273 - val_acc: 0.7065
# Epoch 57/100
# 0s - loss: 0.3438 - acc: 0.8795 - val_loss: 0.8347 - val_acc: 0.7337
# Epoch 58/100
# 0s - loss: 0.3370 - acc: 0.8783 - val_loss: 0.9123 - val_acc: 0.6902
# Epoch 59/100
# 0s - loss: 0.3250 - acc: 0.8862 - val_loss: 0.9106 - val_acc: 0.7283
# Epoch 60/100
# 0s - loss: 0.3245 - acc: 0.8820 - val_loss: 1.0507 - val_acc: 0.7065
# Epoch 61/100
# 0s - loss: 0.3248 - acc: 0.8783 - val_loss: 0.9234 - val_acc: 0.6739
# Epoch 62/100
# 0s - loss: 0.3177 - acc: 0.8886 - val_loss: 0.9334 - val_acc: 0.7228
# Epoch 63/100
# 0s - loss: 0.3093 - acc: 0.8856 - val_loss: 0.9092 - val_acc: 0.7609
# Epoch 64/100
# 0s - loss: 0.2810 - acc: 0.8965 - val_loss: 0.9573 - val_acc: 0.7228
# Epoch 65/100
# 0s - loss: 0.2762 - acc: 0.8983 - val_loss: 0.8773 - val_acc: 0.7554
# Epoch 66/100
# 0s - loss: 0.2987 - acc: 0.8868 - val_loss: 0.9228 - val_acc: 0.7065
# Epoch 67/100
# 0s - loss: 0.2954 - acc: 0.8923 - val_loss: 0.8872 - val_acc: 0.7446
# Epoch 68/100
# 0s - loss: 0.3120 - acc: 0.8874 - val_loss: 1.0205 - val_acc: 0.7283
# Epoch 69/100
# 0s - loss: 0.2791 - acc: 0.9019 - val_loss: 0.9494 - val_acc: 0.7174
# Epoch 70/100
# 0s - loss: 0.2865 - acc: 0.9013 - val_loss: 1.0907 - val_acc: 0.6957
# Epoch 71/100
# 0s - loss: 0.2412 - acc: 0.9128 - val_loss: 0.9719 - val_acc: 0.7446
# Epoch 72/100
# 0s - loss: 0.2557 - acc: 0.9050 - val_loss: 0.9514 - val_acc: 0.7337
# Epoch 73/100
# 0s - loss: 0.2514 - acc: 0.9050 - val_loss: 0.8907 - val_acc: 0.7446
# Epoch 74/100
# 0s - loss: 0.2610 - acc: 0.9038 - val_loss: 0.9754 - val_acc: 0.7120
# Epoch 75/100
# 0s - loss: 0.2432 - acc: 0.9056 - val_loss: 0.8954 - val_acc: 0.7391
# Epoch 76/100
# 0s - loss: 0.2324 - acc: 0.9134 - val_loss: 0.9531 - val_acc: 0.7391
# Epoch 77/100
# 0s - loss: 0.2678 - acc: 0.9001 - val_loss: 0.9666 - val_acc: 0.7337
# Epoch 78/100
# 0s - loss: 0.2239 - acc: 0.9159 - val_loss: 1.0264 - val_acc: 0.7174
# Epoch 79/100
# 0s - loss: 0.1936 - acc: 0.9298 - val_loss: 0.9261 - val_acc: 0.7609
# Epoch 80/100
# 0s - loss: 0.2233 - acc: 0.9286 - val_loss: 1.0559 - val_acc: 0.7174
# Epoch 81/100
# 0s - loss: 0.2266 - acc: 0.9146 - val_loss: 0.9970 - val_acc: 0.7337
# Epoch 82/100
# 0s - loss: 0.2139 - acc: 0.9213 - val_loss: 1.0150 - val_acc: 0.7446
# Epoch 83/100
# 0s - loss: 0.2255 - acc: 0.9153 - val_loss: 1.1106 - val_acc: 0.7120
# Epoch 84/100
# 0s - loss: 0.2010 - acc: 0.9280 - val_loss: 1.0602 - val_acc: 0.7228
# Epoch 85/100
# 0s - loss: 0.2354 - acc: 0.9092 - val_loss: 1.0833 - val_acc: 0.7446
# Epoch 86/100
# 0s - loss: 0.2259 - acc: 0.9153 - val_loss: 1.1315 - val_acc: 0.7228
# Epoch 87/100
# 0s - loss: 0.2340 - acc: 0.9110 - val_loss: 1.0759 - val_acc: 0.7391
# Epoch 88/100
# 0s - loss: 0.1832 - acc: 0.9358 - val_loss: 1.0640 - val_acc: 0.7500
# Epoch 89/100
# 0s - loss: 0.2340 - acc: 0.9219 - val_loss: 0.9827 - val_acc: 0.7174
# Epoch 90/100
# 0s - loss: 0.2086 - acc: 0.9237 - val_loss: 1.0968 - val_acc: 0.7228
# Epoch 91/100
# 0s - loss: 0.1999 - acc: 0.9207 - val_loss: 1.0809 - val_acc: 0.7228
# Epoch 92/100
# 0s - loss: 0.1830 - acc: 0.9346 - val_loss: 1.1952 - val_acc: 0.7337
# Epoch 93/100
# 0s - loss: 0.1934 - acc: 0.9280 - val_loss: 1.2310 - val_acc: 0.6957
# Epoch 94/100
# 0s - loss: 0.2198 - acc: 0.9195 - val_loss: 1.1345 - val_acc: 0.6957
# Epoch 95/100
# 0s - loss: 0.1917 - acc: 0.9346 - val_loss: 1.1203 - val_acc: 0.7283
# Epoch 96/100
# 0s - loss: 0.1641 - acc: 0.9419 - val_loss: 1.0755 - val_acc: 0.7391
# Epoch 97/100
# 0s - loss: 0.1785 - acc: 0.9377 - val_loss: 1.1679 - val_acc: 0.7120
# Epoch 98/100
# 0s - loss: 0.1648 - acc: 0.9419 - val_loss: 1.1742 - val_acc: 0.7065
# Epoch 99/100
# 0s - loss: 0.1930 - acc: 0.9304 - val_loss: 1.1649 - val_acc: 0.7283
# Epoch 100/100
# 0s - loss: 0.1769 - acc: 0.9407 - val_loss: 1.1500 - val_acc: 0.7228
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 0s - loss: 2.6760 - acc: 0.3656 - val_loss: 1.2167 - val_acc: 0.5652
# Epoch 2/100
# 0s - loss: 1.4345 - acc: 0.5036 - val_loss: 1.1130 - val_acc: 0.5978
# Epoch 3/100
# 0s - loss: 1.2860 - acc: 0.5309 - val_loss: 1.0673 - val_acc: 0.6413
# Epoch 4/100
# 0s - loss: 1.2283 - acc: 0.5690 - val_loss: 1.0790 - val_acc: 0.5870
# Epoch 5/100
# 0s - loss: 1.1804 - acc: 0.5587 - val_loss: 0.9984 - val_acc: 0.6304
# Epoch 6/100
# 0s - loss: 1.1059 - acc: 0.5896 - val_loss: 1.0285 - val_acc: 0.6467
# Epoch 7/100
# 0s - loss: 1.0882 - acc: 0.5920 - val_loss: 0.9601 - val_acc: 0.6576
# Epoch 8/100
# 0s - loss: 1.0613 - acc: 0.6138 - val_loss: 0.8979 - val_acc: 0.6630
# Epoch 9/100
# 0s - loss: 1.0019 - acc: 0.6314 - val_loss: 0.8671 - val_acc: 0.6848
# Epoch 10/100
# 0s - loss: 0.9962 - acc: 0.6338 - val_loss: 0.8701 - val_acc: 0.6793
# Epoch 11/100
# 0s - loss: 0.9762 - acc: 0.6501 - val_loss: 0.9081 - val_acc: 0.6522
# Epoch 12/100
# 0s - loss: 0.9319 - acc: 0.6538 - val_loss: 0.8231 - val_acc: 0.7120
# Epoch 13/100
# 0s - loss: 0.9376 - acc: 0.6634 - val_loss: 0.8059 - val_acc: 0.7011
# Epoch 14/100
# 0s - loss: 0.8989 - acc: 0.6701 - val_loss: 0.8086 - val_acc: 0.7065
# Epoch 15/100
# 0s - loss: 0.8942 - acc: 0.6768 - val_loss: 0.8048 - val_acc: 0.7174
# Epoch 16/100
# 0s - loss: 0.8765 - acc: 0.6822 - val_loss: 0.7772 - val_acc: 0.7174
# Epoch 17/100
# 0s - loss: 0.8544 - acc: 0.7064 - val_loss: 0.7857 - val_acc: 0.7283
# Epoch 18/100
# 0s - loss: 0.8468 - acc: 0.6877 - val_loss: 0.7780 - val_acc: 0.7228
# Epoch 19/100
# 0s - loss: 0.8449 - acc: 0.6931 - val_loss: 0.7760 - val_acc: 0.7065
# Epoch 20/100
# 0s - loss: 0.8182 - acc: 0.7088 - val_loss: 0.7783 - val_acc: 0.7174
# Epoch 21/100
# 0s - loss: 0.7961 - acc: 0.7016 - val_loss: 0.7459 - val_acc: 0.7283
# Epoch 22/100
# 0s - loss: 0.7809 - acc: 0.7185 - val_loss: 0.7601 - val_acc: 0.7391
# Epoch 23/100
# 0s - loss: 0.7597 - acc: 0.7288 - val_loss: 0.7777 - val_acc: 0.7228
# Epoch 24/100
# 0s - loss: 0.7941 - acc: 0.7191 - val_loss: 0.7698 - val_acc: 0.7772
# Epoch 25/100
# 0s - loss: 0.7501 - acc: 0.7222 - val_loss: 0.7548 - val_acc: 0.7554
# Epoch 26/100
# 0s - loss: 0.7628 - acc: 0.7264 - val_loss: 0.7489 - val_acc: 0.7500
# Epoch 27/100
# 0s - loss: 0.7387 - acc: 0.7391 - val_loss: 0.7628 - val_acc: 0.7609
# Epoch 28/100
# 0s - loss: 0.7093 - acc: 0.7488 - val_loss: 0.7184 - val_acc: 0.7663
# Epoch 29/100
# 0s - loss: 0.7162 - acc: 0.7409 - val_loss: 0.7346 - val_acc: 0.7500
# Epoch 30/100
# 0s - loss: 0.6918 - acc: 0.7433 - val_loss: 0.7351 - val_acc: 0.7717
# Epoch 31/100
# 0s - loss: 0.6826 - acc: 0.7567 - val_loss: 0.7060 - val_acc: 0.7500
# Epoch 32/100
# 0s - loss: 0.6810 - acc: 0.7518 - val_loss: 0.7383 - val_acc: 0.7554
# Epoch 33/100
# 0s - loss: 0.6684 - acc: 0.7645 - val_loss: 0.7370 - val_acc: 0.7609
# Epoch 34/100
# 0s - loss: 0.6728 - acc: 0.7500 - val_loss: 0.7421 - val_acc: 0.7772
# Epoch 35/100
# 0s - loss: 0.6572 - acc: 0.7669 - val_loss: 0.7557 - val_acc: 0.7772
# Epoch 36/100
# 0s - loss: 0.6658 - acc: 0.7603 - val_loss: 0.8219 - val_acc: 0.7554
# Epoch 37/100
# 0s - loss: 0.6470 - acc: 0.7736 - val_loss: 0.7179 - val_acc: 0.7880
# Epoch 38/100
# 0s - loss: 0.6414 - acc: 0.7724 - val_loss: 0.8166 - val_acc: 0.7337
# Epoch 39/100
# 0s - loss: 0.6316 - acc: 0.7669 - val_loss: 0.7135 - val_acc: 0.7609
# Epoch 40/100
# 0s - loss: 0.6111 - acc: 0.7863 - val_loss: 0.8022 - val_acc: 0.7663
# Epoch 41/100
# 0s - loss: 0.6067 - acc: 0.7881 - val_loss: 0.7395 - val_acc: 0.7609
# Epoch 42/100
# 0s - loss: 0.6056 - acc: 0.7766 - val_loss: 0.8102 - val_acc: 0.7609
# Epoch 43/100
# 0s - loss: 0.5853 - acc: 0.7906 - val_loss: 0.7443 - val_acc: 0.7663
# Epoch 44/100
# 0s - loss: 0.5765 - acc: 0.7900 - val_loss: 0.7452 - val_acc: 0.7609
# Epoch 45/100
# 0s - loss: 0.5746 - acc: 0.7900 - val_loss: 0.8377 - val_acc: 0.7554
# Epoch 46/100
# 0s - loss: 0.5736 - acc: 0.7912 - val_loss: 0.8144 - val_acc: 0.7554
# Epoch 47/100
# 0s - loss: 0.5449 - acc: 0.7948 - val_loss: 0.7828 - val_acc: 0.7717
# Epoch 48/100
# 0s - loss: 0.5386 - acc: 0.7936 - val_loss: 0.8070 - val_acc: 0.7826
# Epoch 49/100
# 0s - loss: 0.5262 - acc: 0.7996 - val_loss: 0.7847 - val_acc: 0.7554
# Epoch 50/100
# 0s - loss: 0.5116 - acc: 0.8075 - val_loss: 0.7551 - val_acc: 0.7554
# Epoch 51/100
# 0s - loss: 0.5060 - acc: 0.8105 - val_loss: 0.7611 - val_acc: 0.7717
# Epoch 52/100
# 0s - loss: 0.5124 - acc: 0.8075 - val_loss: 0.8367 - val_acc: 0.7337
# Epoch 53/100
# 0s - loss: 0.5235 - acc: 0.8021 - val_loss: 0.7754 - val_acc: 0.7663
# Epoch 54/100
# 0s - loss: 0.5096 - acc: 0.8172 - val_loss: 0.8478 - val_acc: 0.7554
# Epoch 55/100
# 0s - loss: 0.4863 - acc: 0.8184 - val_loss: 0.8046 - val_acc: 0.7500
# Epoch 56/100
# 0s - loss: 0.4805 - acc: 0.8317 - val_loss: 0.8305 - val_acc: 0.7391
# Epoch 57/100
# 0s - loss: 0.4699 - acc: 0.8220 - val_loss: 0.7856 - val_acc: 0.7717
# Epoch 58/100
# 0s - loss: 0.4605 - acc: 0.8402 - val_loss: 0.7985 - val_acc: 0.7826
# Epoch 59/100
# 0s - loss: 0.4661 - acc: 0.8190 - val_loss: 0.7845 - val_acc: 0.7554
# Epoch 60/100
# 0s - loss: 0.4842 - acc: 0.8190 - val_loss: 0.8664 - val_acc: 0.7500
# Epoch 61/100
# 0s - loss: 0.4645 - acc: 0.8226 - val_loss: 0.8717 - val_acc: 0.7554
# Epoch 62/100
# 0s - loss: 0.4506 - acc: 0.8251 - val_loss: 0.8733 - val_acc: 0.7500
# Epoch 63/100
# 0s - loss: 0.4332 - acc: 0.8408 - val_loss: 0.8378 - val_acc: 0.7391
# Epoch 64/100
# 0s - loss: 0.4699 - acc: 0.8305 - val_loss: 0.8418 - val_acc: 0.7500
# Epoch 65/100
# 0s - loss: 0.4349 - acc: 0.8366 - val_loss: 0.9113 - val_acc: 0.7174
# Epoch 66/100
# 0s - loss: 0.4608 - acc: 0.8329 - val_loss: 0.8186 - val_acc: 0.7663
# Epoch 67/100
# 0s - loss: 0.4188 - acc: 0.8487 - val_loss: 0.8702 - val_acc: 0.7554
# Epoch 68/100
# 0s - loss: 0.4346 - acc: 0.8372 - val_loss: 0.8383 - val_acc: 0.7609
# Epoch 69/100
# 0s - loss: 0.4113 - acc: 0.8469 - val_loss: 0.8834 - val_acc: 0.7174
# Epoch 70/100
# 0s - loss: 0.3743 - acc: 0.8590 - val_loss: 0.8939 - val_acc: 0.7500
# Epoch 71/100
# 0s - loss: 0.3794 - acc: 0.8511 - val_loss: 0.8580 - val_acc: 0.7228
# Epoch 72/100
# 0s - loss: 0.4150 - acc: 0.8462 - val_loss: 0.9215 - val_acc: 0.7500
# Epoch 73/100
# 0s - loss: 0.4037 - acc: 0.8481 - val_loss: 0.8593 - val_acc: 0.7446
# Epoch 74/100
# 0s - loss: 0.3870 - acc: 0.8608 - val_loss: 0.9334 - val_acc: 0.7446
# Epoch 75/100
# 0s - loss: 0.3980 - acc: 0.8547 - val_loss: 0.9168 - val_acc: 0.7554
# Epoch 76/100
# 0s - loss: 0.3978 - acc: 0.8499 - val_loss: 0.8532 - val_acc: 0.7500
# Epoch 77/100
# 0s - loss: 0.3783 - acc: 0.8638 - val_loss: 0.9202 - val_acc: 0.7391
# Epoch 78/100
# 0s - loss: 0.3747 - acc: 0.8638 - val_loss: 0.9759 - val_acc: 0.7337
# Epoch 79/100
# 0s - loss: 0.3834 - acc: 0.8565 - val_loss: 0.9630 - val_acc: 0.7500
# Epoch 80/100
# 0s - loss: 0.3660 - acc: 0.8590 - val_loss: 0.9004 - val_acc: 0.7500
# Epoch 81/100
# 0s - loss: 0.3538 - acc: 0.8644 - val_loss: 0.9957 - val_acc: 0.7391
# Epoch 82/100
# 0s - loss: 0.3690 - acc: 0.8620 - val_loss: 0.8762 - val_acc: 0.7500
# Epoch 83/100
# 0s - loss: 0.3575 - acc: 0.8650 - val_loss: 0.9191 - val_acc: 0.7609
# Epoch 84/100
# 0s - loss: 0.3469 - acc: 0.8765 - val_loss: 0.9707 - val_acc: 0.7554
# Epoch 85/100
# 0s - loss: 0.3295 - acc: 0.8814 - val_loss: 0.9246 - val_acc: 0.7500
# Epoch 86/100
# 0s - loss: 0.3256 - acc: 0.8765 - val_loss: 0.9628 - val_acc: 0.7500
# Epoch 87/100
# 0s - loss: 0.3550 - acc: 0.8717 - val_loss: 0.9609 - val_acc: 0.7283
# Epoch 88/100
# 0s - loss: 0.3325 - acc: 0.8783 - val_loss: 1.0172 - val_acc: 0.7391
# Epoch 89/100
# 0s - loss: 0.3322 - acc: 0.8808 - val_loss: 0.9036 - val_acc: 0.7772
# Epoch 90/100
# 0s - loss: 0.3384 - acc: 0.8711 - val_loss: 0.9901 - val_acc: 0.7283
# Epoch 91/100
# 0s - loss: 0.3355 - acc: 0.8686 - val_loss: 0.9736 - val_acc: 0.7500
# Epoch 92/100
# 0s - loss: 0.3430 - acc: 0.8741 - val_loss: 1.0344 - val_acc: 0.7337
# Epoch 93/100
# 0s - loss: 0.3288 - acc: 0.8699 - val_loss: 1.0310 - val_acc: 0.7228
# Epoch 94/100
# 0s - loss: 0.3041 - acc: 0.8856 - val_loss: 1.0237 - val_acc: 0.7554
# Epoch 95/100
# 0s - loss: 0.3512 - acc: 0.8747 - val_loss: 0.9397 - val_acc: 0.7500
# Epoch 96/100
# 0s - loss: 0.3057 - acc: 0.8838 - val_loss: 0.9711 - val_acc: 0.7446
# Epoch 97/100
# 0s - loss: 0.3055 - acc: 0.8898 - val_loss: 0.9607 - val_acc: 0.7446
# Epoch 98/100
# 0s - loss: 0.3224 - acc: 0.8832 - val_loss: 1.1105 - val_acc: 0.7065
# Epoch 99/100
# 0s - loss: 0.3050 - acc: 0.8868 - val_loss: 0.9241 - val_acc: 0.7663
# Epoch 100/100
# 0s - loss: 0.2986 - acc: 0.8910 - val_loss: 1.0308 - val_acc: 0.7283
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 0s - loss: 3.0730 - acc: 0.3680 - val_loss: 1.2570 - val_acc: 0.5326
# Epoch 2/100
# 0s - loss: 1.4918 - acc: 0.4516 - val_loss: 1.2230 - val_acc: 0.5435
# Epoch 3/100
# 0s - loss: 1.3319 - acc: 0.5176 - val_loss: 1.1919 - val_acc: 0.5924
# Epoch 4/100
# 0s - loss: 1.3063 - acc: 0.5381 - val_loss: 1.1330 - val_acc: 0.5978
# Epoch 5/100
# 0s - loss: 1.2257 - acc: 0.5678 - val_loss: 1.0994 - val_acc: 0.6359
# Epoch 6/100
# 0s - loss: 1.1998 - acc: 0.5605 - val_loss: 1.0542 - val_acc: 0.6304
# Epoch 7/100
# 0s - loss: 1.1698 - acc: 0.5769 - val_loss: 1.0256 - val_acc: 0.6304
# Epoch 8/100
# 0s - loss: 1.1450 - acc: 0.5854 - val_loss: 0.9885 - val_acc: 0.6359
# Epoch 9/100
# 0s - loss: 1.1153 - acc: 0.5950 - val_loss: 0.9525 - val_acc: 0.6630
# Epoch 10/100
# 0s - loss: 1.0917 - acc: 0.5914 - val_loss: 0.9814 - val_acc: 0.6576
# Epoch 11/100
# 0s - loss: 1.0706 - acc: 0.6096 - val_loss: 0.9416 - val_acc: 0.6467
# Epoch 12/100
# 0s - loss: 1.0665 - acc: 0.6041 - val_loss: 0.9101 - val_acc: 0.6902
# Epoch 13/100
# 0s - loss: 1.0692 - acc: 0.6144 - val_loss: 0.8978 - val_acc: 0.6739
# Epoch 14/100
# 0s - loss: 1.0349 - acc: 0.6289 - val_loss: 0.8924 - val_acc: 0.6957
# Epoch 15/100
# 0s - loss: 1.0055 - acc: 0.6326 - val_loss: 0.8613 - val_acc: 0.7065
# Epoch 16/100
# 0s - loss: 1.0039 - acc: 0.6398 - val_loss: 0.8510 - val_acc: 0.7120
# Epoch 17/100
# 0s - loss: 0.9886 - acc: 0.6562 - val_loss: 0.8358 - val_acc: 0.6902
# Epoch 18/100
# 0s - loss: 0.9911 - acc: 0.6483 - val_loss: 0.8321 - val_acc: 0.6739
# Epoch 19/100
# 0s - loss: 0.9507 - acc: 0.6513 - val_loss: 0.8060 - val_acc: 0.6957
# Epoch 20/100
# 0s - loss: 0.9392 - acc: 0.6574 - val_loss: 0.7968 - val_acc: 0.6957
# Epoch 21/100
# 0s - loss: 0.9331 - acc: 0.6556 - val_loss: 0.8133 - val_acc: 0.7065
# Epoch 22/100
# 0s - loss: 0.9398 - acc: 0.6580 - val_loss: 0.7762 - val_acc: 0.7120
# Epoch 23/100
# 0s - loss: 0.9236 - acc: 0.6616 - val_loss: 0.7777 - val_acc: 0.7228
# Epoch 24/100
# 0s - loss: 0.9289 - acc: 0.6646 - val_loss: 0.7999 - val_acc: 0.7120
# Epoch 25/100
# 0s - loss: 0.9171 - acc: 0.6731 - val_loss: 0.8056 - val_acc: 0.7011
# Epoch 26/100
# 0s - loss: 0.8975 - acc: 0.6719 - val_loss: 0.7663 - val_acc: 0.7174
# Epoch 27/100
# 0s - loss: 0.8870 - acc: 0.6840 - val_loss: 0.7726 - val_acc: 0.7283
# Epoch 28/100
# 0s - loss: 0.8918 - acc: 0.6834 - val_loss: 0.7906 - val_acc: 0.7065
# Epoch 29/100
# 0s - loss: 0.8729 - acc: 0.6792 - val_loss: 0.7556 - val_acc: 0.7174
# Epoch 30/100
# 0s - loss: 0.8924 - acc: 0.6846 - val_loss: 0.7533 - val_acc: 0.7337
# Epoch 31/100
# 0s - loss: 0.8417 - acc: 0.6985 - val_loss: 0.7243 - val_acc: 0.7337
# Epoch 32/100
# 0s - loss: 0.8685 - acc: 0.6985 - val_loss: 0.7488 - val_acc: 0.7500
# Epoch 33/100
# 0s - loss: 0.8448 - acc: 0.6967 - val_loss: 0.7273 - val_acc: 0.7337
# Epoch 34/100
# 0s - loss: 0.8343 - acc: 0.6949 - val_loss: 0.7433 - val_acc: 0.7500
# Epoch 35/100
# 0s - loss: 0.8484 - acc: 0.6985 - val_loss: 0.7408 - val_acc: 0.7337
# Epoch 36/100
# 0s - loss: 0.8476 - acc: 0.7016 - val_loss: 0.7482 - val_acc: 0.7500
# Epoch 37/100
# 0s - loss: 0.8471 - acc: 0.7088 - val_loss: 0.7680 - val_acc: 0.7283
# Epoch 38/100
# 0s - loss: 0.8358 - acc: 0.7010 - val_loss: 0.7119 - val_acc: 0.7446
# Epoch 39/100
# 0s - loss: 0.8127 - acc: 0.7119 - val_loss: 0.7180 - val_acc: 0.7554
# Epoch 40/100
# 0s - loss: 0.8241 - acc: 0.7034 - val_loss: 0.7205 - val_acc: 0.7554
# Epoch 41/100
# 0s - loss: 0.7979 - acc: 0.7179 - val_loss: 0.7216 - val_acc: 0.7500
# Epoch 42/100
# 0s - loss: 0.8047 - acc: 0.7173 - val_loss: 0.7073 - val_acc: 0.7446
# Epoch 43/100
# 0s - loss: 0.8023 - acc: 0.7064 - val_loss: 0.7156 - val_acc: 0.7500
# Epoch 44/100
# 0s - loss: 0.8059 - acc: 0.7161 - val_loss: 0.6730 - val_acc: 0.7609
# Epoch 45/100
# 0s - loss: 0.7813 - acc: 0.7191 - val_loss: 0.7194 - val_acc: 0.7554
# Epoch 46/100
# 0s - loss: 0.7997 - acc: 0.7167 - val_loss: 0.7239 - val_acc: 0.7500
# Epoch 47/100
# 0s - loss: 0.8205 - acc: 0.6985 - val_loss: 0.7206 - val_acc: 0.7446
# Epoch 48/100
# 0s - loss: 0.7947 - acc: 0.7113 - val_loss: 0.7145 - val_acc: 0.7500
# Epoch 49/100
# 0s - loss: 0.7861 - acc: 0.7197 - val_loss: 0.7421 - val_acc: 0.7283
# Epoch 50/100
# 0s - loss: 0.7778 - acc: 0.7222 - val_loss: 0.6766 - val_acc: 0.7554
# Epoch 51/100
# 0s - loss: 0.7745 - acc: 0.7191 - val_loss: 0.7203 - val_acc: 0.7391
# Epoch 52/100
# 0s - loss: 0.7401 - acc: 0.7367 - val_loss: 0.7013 - val_acc: 0.7337
# Epoch 53/100
# 0s - loss: 0.7850 - acc: 0.7125 - val_loss: 0.7165 - val_acc: 0.7283
# Epoch 54/100
# 0s - loss: 0.7596 - acc: 0.7294 - val_loss: 0.6906 - val_acc: 0.7717
# Epoch 55/100
# 0s - loss: 0.7743 - acc: 0.7173 - val_loss: 0.7408 - val_acc: 0.7391
# Epoch 56/100
# 0s - loss: 0.7534 - acc: 0.7288 - val_loss: 0.6883 - val_acc: 0.7663
# Epoch 57/100
# 0s - loss: 0.7321 - acc: 0.7446 - val_loss: 0.6976 - val_acc: 0.7554
# Epoch 58/100
# 0s - loss: 0.7740 - acc: 0.7197 - val_loss: 0.7091 - val_acc: 0.7500
# Epoch 59/100
# 0s - loss: 0.7594 - acc: 0.7288 - val_loss: 0.7267 - val_acc: 0.7446
# Epoch 60/100
# 0s - loss: 0.7609 - acc: 0.7240 - val_loss: 0.6840 - val_acc: 0.7609
# Epoch 61/100
# 0s - loss: 0.7256 - acc: 0.7397 - val_loss: 0.7234 - val_acc: 0.7446
# Epoch 62/100
# 0s - loss: 0.7503 - acc: 0.7294 - val_loss: 0.7197 - val_acc: 0.7283
# Epoch 63/100
# 0s - loss: 0.7482 - acc: 0.7373 - val_loss: 0.7224 - val_acc: 0.7283
# Epoch 64/100
# 0s - loss: 0.7441 - acc: 0.7240 - val_loss: 0.7057 - val_acc: 0.7609
# Epoch 65/100
# 0s - loss: 0.7399 - acc: 0.7300 - val_loss: 0.7381 - val_acc: 0.7283
# Epoch 66/100
# 0s - loss: 0.7470 - acc: 0.7288 - val_loss: 0.7160 - val_acc: 0.7717
# Epoch 67/100
# 0s - loss: 0.7414 - acc: 0.7276 - val_loss: 0.7346 - val_acc: 0.7446
# Epoch 68/100
# 0s - loss: 0.7424 - acc: 0.7349 - val_loss: 0.6853 - val_acc: 0.7717
# Epoch 69/100
# 0s - loss: 0.7404 - acc: 0.7343 - val_loss: 0.7122 - val_acc: 0.7446
# Epoch 70/100
# 0s - loss: 0.7129 - acc: 0.7554 - val_loss: 0.7541 - val_acc: 0.7554
# Epoch 71/100
# 0s - loss: 0.7298 - acc: 0.7300 - val_loss: 0.7211 - val_acc: 0.7554
# Epoch 72/100
# 0s - loss: 0.7278 - acc: 0.7409 - val_loss: 0.7312 - val_acc: 0.7554
# Epoch 73/100
# 0s - loss: 0.7004 - acc: 0.7536 - val_loss: 0.6933 - val_acc: 0.7446
# Epoch 74/100
# 0s - loss: 0.6978 - acc: 0.7579 - val_loss: 0.7236 - val_acc: 0.7337
# Epoch 75/100
# 0s - loss: 0.6910 - acc: 0.7567 - val_loss: 0.7342 - val_acc: 0.7337
# Epoch 76/100
# 0s - loss: 0.7113 - acc: 0.7306 - val_loss: 0.7437 - val_acc: 0.7283
# Epoch 77/100
# 0s - loss: 0.7328 - acc: 0.7294 - val_loss: 0.6980 - val_acc: 0.7283
# Epoch 78/100
# 0s - loss: 0.6951 - acc: 0.7476 - val_loss: 0.6825 - val_acc: 0.7663
# Epoch 79/100
# 0s - loss: 0.7095 - acc: 0.7421 - val_loss: 0.7321 - val_acc: 0.7554
# Epoch 80/100
# 0s - loss: 0.6903 - acc: 0.7530 - val_loss: 0.7346 - val_acc: 0.7283
# Epoch 81/100
# 0s - loss: 0.7072 - acc: 0.7385 - val_loss: 0.7442 - val_acc: 0.7609
# Epoch 82/100
# 0s - loss: 0.7167 - acc: 0.7500 - val_loss: 0.7344 - val_acc: 0.7500
# Epoch 83/100
# 0s - loss: 0.6833 - acc: 0.7579 - val_loss: 0.7173 - val_acc: 0.7283
# Epoch 84/100
# 0s - loss: 0.7002 - acc: 0.7500 - val_loss: 0.7307 - val_acc: 0.7609
# Epoch 85/100
# 0s - loss: 0.7036 - acc: 0.7567 - val_loss: 0.7393 - val_acc: 0.7446
# Epoch 86/100
# 0s - loss: 0.6746 - acc: 0.7579 - val_loss: 0.7212 - val_acc: 0.7283
# Epoch 87/100
# 0s - loss: 0.6847 - acc: 0.7488 - val_loss: 0.7506 - val_acc: 0.7228
# Epoch 88/100
# 0s - loss: 0.6952 - acc: 0.7518 - val_loss: 0.7005 - val_acc: 0.7391
# Epoch 89/100
# 0s - loss: 0.6800 - acc: 0.7506 - val_loss: 0.7137 - val_acc: 0.7554
# Epoch 90/100
# 0s - loss: 0.6879 - acc: 0.7494 - val_loss: 0.7504 - val_acc: 0.7554
# Epoch 91/100
# 0s - loss: 0.6831 - acc: 0.7488 - val_loss: 0.7484 - val_acc: 0.7500
# Epoch 92/100
# 0s - loss: 0.6693 - acc: 0.7603 - val_loss: 0.7163 - val_acc: 0.7554
# Epoch 93/100
# 0s - loss: 0.6589 - acc: 0.7633 - val_loss: 0.7133 - val_acc: 0.7446
# Epoch 94/100
# 0s - loss: 0.6779 - acc: 0.7603 - val_loss: 0.7677 - val_acc: 0.7228
# Epoch 95/100
# 0s - loss: 0.6661 - acc: 0.7609 - val_loss: 0.7233 - val_acc: 0.7391
# Epoch 96/100
# 0s - loss: 0.6424 - acc: 0.7651 - val_loss: 0.6957 - val_acc: 0.7554
# Epoch 97/100
# 0s - loss: 0.7034 - acc: 0.7518 - val_loss: 0.7381 - val_acc: 0.7391
# Epoch 98/100
# 0s - loss: 0.6684 - acc: 0.7579 - val_loss: 0.7037 - val_acc: 0.7228
# Epoch 99/100
# 0s - loss: 0.6715 - acc: 0.7561 - val_loss: 0.6759 - val_acc: 0.7391
# Epoch 100/100
# 0s - loss: 0.6657 - acc: 0.7530 - val_loss: 0.7271 - val_acc: 0.7391
# Result saved into 08_dropout_loss/acc.png

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
skp = 10
plt.figure(0)
#plt.subplot(121)
plt.plot(range(len(loss_adam_drp10)), loss_adam_drp10,label='Training_drp10')
plt.plot(range(len(val_loss_adam_drp10)), val_loss_adam_drp10,label='Validation_drp10')

plt.plot(range(len(loss_adam_drp20)), loss_adam_drp20,label='Training_drp20')
plt.plot(range(len(val_loss_adam_drp20)), val_loss_adam_drp20,label='Validation_drp20')

plt.plot(range(len(loss_adam_drp40)), loss_adam_drp40,label='Training_drp40')
plt.plot(range(len(val_loss_adam_drp40)), val_loss_adam_drp40,label='Validation_drp40')

plt.legend()
plt.title('Loss')

plt.show()

plt.plot(range(len(acc_adam_drp10)), acc_adam_drp10,label='Training_drp10')
plt.plot(range(len(val_acc_adam_drp10)), val_acc_adam_drp10,label='Validation_drp10')

plt.plot(range(len(acc_adam_drp20)), acc_adam_drp20,label='Training_drp20')
plt.plot(range(len(val_acc_adam_drp20)), val_acc_adam_drp20,label='Validation_drp20')

plt.plot(range(len(acc_adam_drp40)), acc_adam_drp40,label='Training_drp40')
plt.plot(range(len(val_acc_adam_drp40)), val_acc_adam_drp40,label='Validation_drp40')

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)
plt.title('Accuracy')

plt.show()

# %% [markdown]
# ## 09_batchnormalization
# ---
# 比較 dropout 和 batchnormaization 的效果

# %%
# %load 09_batchnorm.py
''' Import theano and numpy '''
from __future__ import print_function
from past.builtins import execfile
import numpy as np
execfile('00_readingInput.py')

''' set the size of mini-batch and number of epochs'''
batch_size = 32
epochs = 100

''' Import keras to build a DL model '''
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import BatchNormalization
from keras.optimizers import SGD, Adam, RMSprop, Adagrad

def create_model_withDrp_bn(ratio_dropout, bn = False):
    print('Building current best model with Dropout = %g' % ratio_dropout)
    model_adam = Sequential()
    model_adam.add(Dense(128, input_dim=200))
    model_adam.add(Activation('relu'))
    if bn:
        model_adam.add(BatchNormalization())
    model_adam.add(Dropout(ratio_dropout))
    
    model_adam.add(Dense(256))
    if bn:
        model_adam.add(BatchNormalization())
    model_adam.add(Activation('relu'))
    model_adam.add(Dropout(ratio_dropout))
    
    model_adam.add(Dense(5))
    model_adam.add(Activation('softmax'))
    ##
    model_adam.compile(loss= 'categorical_crossentropy',
              		optimizer='Adam',
              		metrics=['accuracy'])
    return model_adam

model_adam_drp40 = create_model_withDrp(0.4)
model_adam_bn = create_model_withDrp_bn(0, bn = True)
model_adam_bn_ks = create_model_withDrp_bn(0, bn = True)
model_adam_drp40_bn = create_model_withDrp_bn(0.4, bn = True)

'''Fit models and use validation_split=0.1 '''
history_adam_drp40 = model_adam_drp40.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

history_adam_bn = model_adam_bn.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

history_adam_drp40_bn = model_adam_drp40_bn.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)

batch_size = 2
history_adam_bn_ks = model_adam_bn_ks.fit(X_train, Y_train,
							batch_size=batch_size,
							epochs=epochs,
							verbose=2,
							shuffle=True,
                    		validation_split=0.1)



def get_result(history_model):
	train_loss = history_model.history.get('loss')
	train_acc = history_model.history.get('acc')
	valid_loss = history_model.history.get('val_loss')
	valid_acc = history_model.history.get('val_acc')
	return train_loss, train_acc, valid_loss, valid_acc

loss_adam_drp40, acc_adam_drp40, val_loss_adam_drp40, val_acc_adam_drp40 = get_result(history_adam_drp40)
loss_adam_bn, acc_adam_bn, val_loss_adam_bn, val_acc_adam_bn = get_result(history_adam_bn)
loss_adam_bn_ks, acc_adam_bn_ks, val_loss_adam_bn_ks, val_acc_adam_bn_ks = get_result(history_adam_bn_ks)
loss_adam_drp40_bn, acc_adam_drp40_bn, val_loss_adam_drp40_bn, val_acc_adam_drp40_bn = get_result(history_adam_drp40_bn)
# Out:
# Building current best model with Dropout = 0.4
# Building current best model with Dropout = 0
# Building current best model with Dropout = 0
# Building current best model with Dropout = 0.4
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 2s - loss: 4.2484 - acc: 0.3360 - val_loss: 1.2929 - val_acc: 0.5272
# Epoch 2/100
# 0s - loss: 1.9600 - acc: 0.3959 - val_loss: 1.1958 - val_acc: 0.5870
# Epoch 3/100
# 0s - loss: 1.5044 - acc: 0.4661 - val_loss: 1.2085 - val_acc: 0.6087
# Epoch 4/100
# 0s - loss: 1.3764 - acc: 0.5000 - val_loss: 1.1764 - val_acc: 0.6196
# Epoch 5/100
# 0s - loss: 1.3078 - acc: 0.5260 - val_loss: 1.1780 - val_acc: 0.6196
# Epoch 6/100
# 0s - loss: 1.2639 - acc: 0.5357 - val_loss: 1.1639 - val_acc: 0.6304
# Epoch 7/100
# 0s - loss: 1.2274 - acc: 0.5587 - val_loss: 1.1179 - val_acc: 0.6413
# Epoch 8/100
# 0s - loss: 1.1846 - acc: 0.5757 - val_loss: 1.0616 - val_acc: 0.6576
# Epoch 9/100
# 0s - loss: 1.1585 - acc: 0.5726 - val_loss: 1.0218 - val_acc: 0.6304
# Epoch 10/100
# 0s - loss: 1.1358 - acc: 0.5938 - val_loss: 1.0273 - val_acc: 0.6576
# Epoch 11/100
# 0s - loss: 1.1009 - acc: 0.5896 - val_loss: 0.9691 - val_acc: 0.6576
# Epoch 12/100
# 0s - loss: 1.1148 - acc: 0.6077 - val_loss: 0.9621 - val_acc: 0.6739
# Epoch 13/100
# 0s - loss: 1.0858 - acc: 0.6065 - val_loss: 0.9575 - val_acc: 0.6630
# Epoch 14/100
# 0s - loss: 1.0670 - acc: 0.6168 - val_loss: 0.9498 - val_acc: 0.6739
# Epoch 15/100
# 0s - loss: 1.0481 - acc: 0.6320 - val_loss: 0.9347 - val_acc: 0.6413
# Epoch 16/100
# 0s - loss: 1.0355 - acc: 0.6283 - val_loss: 0.9103 - val_acc: 0.7011
# Epoch 17/100
# 0s - loss: 1.0169 - acc: 0.6423 - val_loss: 0.8881 - val_acc: 0.6957
# Epoch 18/100
# 0s - loss: 0.9903 - acc: 0.6423 - val_loss: 0.8499 - val_acc: 0.7011
# Epoch 19/100
# 0s - loss: 0.9918 - acc: 0.6483 - val_loss: 0.8461 - val_acc: 0.7120
# Epoch 20/100
# 0s - loss: 0.9843 - acc: 0.6471 - val_loss: 0.8445 - val_acc: 0.7228
# Epoch 21/100
# 0s - loss: 0.9576 - acc: 0.6592 - val_loss: 0.8511 - val_acc: 0.6793
# Epoch 22/100
# 0s - loss: 0.9392 - acc: 0.6640 - val_loss: 0.8255 - val_acc: 0.7283
# Epoch 23/100
# 0s - loss: 0.9546 - acc: 0.6538 - val_loss: 0.8491 - val_acc: 0.7174
# Epoch 24/100
# 0s - loss: 0.9322 - acc: 0.6731 - val_loss: 0.8086 - val_acc: 0.7174
# Epoch 25/100
# 0s - loss: 0.9204 - acc: 0.6780 - val_loss: 0.8175 - val_acc: 0.7011
# Epoch 26/100
# 0s - loss: 0.9106 - acc: 0.6755 - val_loss: 0.8168 - val_acc: 0.6957
# Epoch 27/100
# 0s - loss: 0.9040 - acc: 0.6713 - val_loss: 0.8032 - val_acc: 0.7174
# Epoch 28/100
# 0s - loss: 0.8890 - acc: 0.6755 - val_loss: 0.7998 - val_acc: 0.7337
# Epoch 29/100
# 0s - loss: 0.8984 - acc: 0.6762 - val_loss: 0.7908 - val_acc: 0.7174
# Epoch 30/100
# 0s - loss: 0.8874 - acc: 0.6798 - val_loss: 0.7751 - val_acc: 0.7120
# Epoch 31/100
# 0s - loss: 0.9001 - acc: 0.6919 - val_loss: 0.7794 - val_acc: 0.7011
# Epoch 32/100
# 0s - loss: 0.8820 - acc: 0.6895 - val_loss: 0.7713 - val_acc: 0.7228
# Epoch 33/100
# 0s - loss: 0.8630 - acc: 0.6810 - val_loss: 0.7920 - val_acc: 0.7391
# Epoch 34/100
# 0s - loss: 0.8580 - acc: 0.7052 - val_loss: 0.7510 - val_acc: 0.7283
# Epoch 35/100
# 0s - loss: 0.8415 - acc: 0.7143 - val_loss: 0.7382 - val_acc: 0.7120
# Epoch 36/100
# 0s - loss: 0.8433 - acc: 0.6937 - val_loss: 0.7506 - val_acc: 0.7120
# Epoch 37/100
# 0s - loss: 0.8300 - acc: 0.7161 - val_loss: 0.7489 - val_acc: 0.7228
# Epoch 38/100
# 0s - loss: 0.8243 - acc: 0.6998 - val_loss: 0.7452 - val_acc: 0.7337
# Epoch 39/100
# 0s - loss: 0.8355 - acc: 0.6998 - val_loss: 0.7390 - val_acc: 0.7283
# Epoch 40/100
# 0s - loss: 0.8203 - acc: 0.7094 - val_loss: 0.7341 - val_acc: 0.7391
# Epoch 41/100
# 0s - loss: 0.8079 - acc: 0.7137 - val_loss: 0.7326 - val_acc: 0.7337
# Epoch 42/100
# 0s - loss: 0.8107 - acc: 0.7228 - val_loss: 0.7889 - val_acc: 0.6793
# Epoch 43/100
# 0s - loss: 0.8116 - acc: 0.7179 - val_loss: 0.7368 - val_acc: 0.7065
# Epoch 44/100
# 0s - loss: 0.7840 - acc: 0.7179 - val_loss: 0.7227 - val_acc: 0.7391
# Epoch 45/100
# 0s - loss: 0.7959 - acc: 0.7222 - val_loss: 0.7271 - val_acc: 0.7283
# Epoch 46/100
# 0s - loss: 0.7752 - acc: 0.7234 - val_loss: 0.7235 - val_acc: 0.7500
# Epoch 47/100
# 0s - loss: 0.7976 - acc: 0.7173 - val_loss: 0.7323 - val_acc: 0.7500
# Epoch 48/100
# 0s - loss: 0.7816 - acc: 0.7234 - val_loss: 0.7253 - val_acc: 0.7500
# Epoch 49/100
# 0s - loss: 0.7746 - acc: 0.7149 - val_loss: 0.6948 - val_acc: 0.7609
# Epoch 50/100
# 0s - loss: 0.7785 - acc: 0.7258 - val_loss: 0.7265 - val_acc: 0.7337
# Epoch 51/100
# 0s - loss: 0.7542 - acc: 0.7318 - val_loss: 0.7266 - val_acc: 0.7554
# Epoch 52/100
# 0s - loss: 0.7526 - acc: 0.7324 - val_loss: 0.6975 - val_acc: 0.7446
# Epoch 53/100
# 0s - loss: 0.7738 - acc: 0.7258 - val_loss: 0.7233 - val_acc: 0.7500
# Epoch 54/100
# 0s - loss: 0.7348 - acc: 0.7379 - val_loss: 0.7204 - val_acc: 0.7283
# Epoch 55/100
# 0s - loss: 0.7623 - acc: 0.7234 - val_loss: 0.7102 - val_acc: 0.7283
# Epoch 56/100
# 0s - loss: 0.7464 - acc: 0.7355 - val_loss: 0.6978 - val_acc: 0.7391
# Epoch 57/100
# 0s - loss: 0.7251 - acc: 0.7397 - val_loss: 0.7093 - val_acc: 0.7391
# Epoch 58/100
# 0s - loss: 0.7321 - acc: 0.7355 - val_loss: 0.7134 - val_acc: 0.7500
# Epoch 59/100
# 0s - loss: 0.7345 - acc: 0.7506 - val_loss: 0.7037 - val_acc: 0.7283
# Epoch 60/100
# 0s - loss: 0.7215 - acc: 0.7373 - val_loss: 0.7297 - val_acc: 0.7065
# Epoch 61/100
# 0s - loss: 0.7458 - acc: 0.7324 - val_loss: 0.6736 - val_acc: 0.7663
# Epoch 62/100
# 0s - loss: 0.7198 - acc: 0.7373 - val_loss: 0.6948 - val_acc: 0.7228
# Epoch 63/100
# 0s - loss: 0.7355 - acc: 0.7373 - val_loss: 0.7225 - val_acc: 0.7065
# Epoch 64/100
# 0s - loss: 0.7221 - acc: 0.7331 - val_loss: 0.7099 - val_acc: 0.7120
# Epoch 65/100
# 0s - loss: 0.6888 - acc: 0.7591 - val_loss: 0.6824 - val_acc: 0.7717
# Epoch 66/100
# 0s - loss: 0.7233 - acc: 0.7355 - val_loss: 0.7224 - val_acc: 0.7228
# Epoch 67/100
# 0s - loss: 0.7057 - acc: 0.7488 - val_loss: 0.7157 - val_acc: 0.7391
# Epoch 68/100
# 0s - loss: 0.6705 - acc: 0.7657 - val_loss: 0.6758 - val_acc: 0.7880
# Epoch 69/100
# 0s - loss: 0.6878 - acc: 0.7530 - val_loss: 0.7015 - val_acc: 0.7500
# Epoch 70/100
# 0s - loss: 0.6575 - acc: 0.7645 - val_loss: 0.7162 - val_acc: 0.7663
# Epoch 71/100
# 0s - loss: 0.7046 - acc: 0.7530 - val_loss: 0.6835 - val_acc: 0.7772
# Epoch 72/100
# 0s - loss: 0.6644 - acc: 0.7669 - val_loss: 0.7099 - val_acc: 0.7500
# Epoch 73/100
# 0s - loss: 0.6656 - acc: 0.7567 - val_loss: 0.7102 - val_acc: 0.7609
# Epoch 74/100
# 0s - loss: 0.6670 - acc: 0.7512 - val_loss: 0.7237 - val_acc: 0.7228
# Epoch 75/100
# 0s - loss: 0.6656 - acc: 0.7730 - val_loss: 0.6968 - val_acc: 0.7500
# Epoch 76/100
# 0s - loss: 0.6951 - acc: 0.7494 - val_loss: 0.6790 - val_acc: 0.7880
# Epoch 77/100
# 0s - loss: 0.6536 - acc: 0.7778 - val_loss: 0.7007 - val_acc: 0.7609
# Epoch 78/100
# 0s - loss: 0.6510 - acc: 0.7724 - val_loss: 0.6790 - val_acc: 0.7772
# Epoch 79/100
# 0s - loss: 0.6591 - acc: 0.7627 - val_loss: 0.6978 - val_acc: 0.7337
# Epoch 80/100
# 0s - loss: 0.6466 - acc: 0.7561 - val_loss: 0.7308 - val_acc: 0.7228
# Epoch 81/100
# 0s - loss: 0.6627 - acc: 0.7621 - val_loss: 0.8025 - val_acc: 0.7065
# Epoch 82/100
# 0s - loss: 0.6612 - acc: 0.7488 - val_loss: 0.7104 - val_acc: 0.7446
# Epoch 83/100
# 0s - loss: 0.6297 - acc: 0.7718 - val_loss: 0.6968 - val_acc: 0.7554
# Epoch 84/100
# 0s - loss: 0.6432 - acc: 0.7621 - val_loss: 0.7191 - val_acc: 0.7717
# Epoch 85/100
# 0s - loss: 0.6420 - acc: 0.7651 - val_loss: 0.7138 - val_acc: 0.7500
# Epoch 86/100
# 0s - loss: 0.6341 - acc: 0.7597 - val_loss: 0.6923 - val_acc: 0.7609
# Epoch 87/100
# 0s - loss: 0.6283 - acc: 0.7754 - val_loss: 0.6958 - val_acc: 0.7717
# Epoch 88/100
# 0s - loss: 0.6291 - acc: 0.7621 - val_loss: 0.7068 - val_acc: 0.7446
# Epoch 89/100
# 0s - loss: 0.6484 - acc: 0.7542 - val_loss: 0.7350 - val_acc: 0.7554
# Epoch 90/100
# 0s - loss: 0.6438 - acc: 0.7724 - val_loss: 0.7168 - val_acc: 0.7391
# Epoch 91/100
# 0s - loss: 0.6230 - acc: 0.7718 - val_loss: 0.6817 - val_acc: 0.7935
# Epoch 92/100
# 0s - loss: 0.6288 - acc: 0.7815 - val_loss: 0.7110 - val_acc: 0.7500
# Epoch 93/100
# 0s - loss: 0.6175 - acc: 0.7875 - val_loss: 0.6959 - val_acc: 0.7609
# Epoch 94/100
# 0s - loss: 0.6344 - acc: 0.7712 - val_loss: 0.6963 - val_acc: 0.7717
# Epoch 95/100
# 0s - loss: 0.6296 - acc: 0.7639 - val_loss: 0.6734 - val_acc: 0.7717
# Epoch 96/100
# 0s - loss: 0.6188 - acc: 0.7706 - val_loss: 0.7130 - val_acc: 0.7554
# Epoch 97/100
# 0s - loss: 0.6186 - acc: 0.7700 - val_loss: 0.7012 - val_acc: 0.7772
# Epoch 98/100
# 0s - loss: 0.6149 - acc: 0.7724 - val_loss: 0.6882 - val_acc: 0.7228
# Epoch 99/100
# 0s - loss: 0.5952 - acc: 0.7797 - val_loss: 0.7407 - val_acc: 0.7446
# Epoch 100/100
# 0s - loss: 0.5842 - acc: 0.7887 - val_loss: 0.6861 - val_acc: 0.7717
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 1s - loss: 1.2937 - acc: 0.5406 - val_loss: 1.5108 - val_acc: 0.5109
# Epoch 2/100
# 0s - loss: 1.0864 - acc: 0.6114 - val_loss: 1.2448 - val_acc: 0.5435
# Epoch 3/100
# 0s - loss: 0.9903 - acc: 0.6374 - val_loss: 1.0682 - val_acc: 0.6576
# Epoch 4/100
# 0s - loss: 0.9333 - acc: 0.6707 - val_loss: 1.0095 - val_acc: 0.6087
# Epoch 5/100
# 0s - loss: 0.8868 - acc: 0.6877 - val_loss: 0.9370 - val_acc: 0.6467
# Epoch 6/100
# 0s - loss: 0.8402 - acc: 0.7046 - val_loss: 0.8415 - val_acc: 0.7174
# Epoch 7/100
# 0s - loss: 0.8045 - acc: 0.7161 - val_loss: 0.7965 - val_acc: 0.7337
# Epoch 8/100
# 0s - loss: 0.7618 - acc: 0.7282 - val_loss: 0.8781 - val_acc: 0.6739
# Epoch 9/100
# 0s - loss: 0.7543 - acc: 0.7367 - val_loss: 0.8551 - val_acc: 0.7065
# Epoch 10/100
# 0s - loss: 0.7386 - acc: 0.7500 - val_loss: 0.8032 - val_acc: 0.7283
# Epoch 11/100
# 0s - loss: 0.7119 - acc: 0.7488 - val_loss: 0.7945 - val_acc: 0.7065
# Epoch 12/100
# 0s - loss: 0.7052 - acc: 0.7530 - val_loss: 0.8036 - val_acc: 0.7120
# Epoch 13/100
# 0s - loss: 0.6773 - acc: 0.7512 - val_loss: 0.7696 - val_acc: 0.7283
# Epoch 14/100
# 0s - loss: 0.6607 - acc: 0.7694 - val_loss: 0.7757 - val_acc: 0.7065
# Epoch 15/100
# 0s - loss: 0.6484 - acc: 0.7815 - val_loss: 0.8562 - val_acc: 0.6576
# Epoch 16/100
# 0s - loss: 0.6348 - acc: 0.7797 - val_loss: 0.8426 - val_acc: 0.7174
# Epoch 17/100
# 0s - loss: 0.6263 - acc: 0.7791 - val_loss: 0.7198 - val_acc: 0.7446
# Epoch 18/100
# 0s - loss: 0.6157 - acc: 0.7760 - val_loss: 0.9714 - val_acc: 0.6793
# Epoch 19/100
# 0s - loss: 0.5998 - acc: 0.7875 - val_loss: 0.8952 - val_acc: 0.7283
# Epoch 20/100
# 0s - loss: 0.5729 - acc: 0.7996 - val_loss: 0.7867 - val_acc: 0.7500
# Epoch 21/100
# 0s - loss: 0.5651 - acc: 0.8045 - val_loss: 0.7373 - val_acc: 0.7174
# Epoch 22/100
# 0s - loss: 0.5657 - acc: 0.7996 - val_loss: 0.7996 - val_acc: 0.7283
# Epoch 23/100
# 0s - loss: 0.5354 - acc: 0.8075 - val_loss: 0.8825 - val_acc: 0.6848
# Epoch 24/100
# 0s - loss: 0.5179 - acc: 0.8057 - val_loss: 0.9825 - val_acc: 0.6413
# Epoch 25/100
# 0s - loss: 0.5112 - acc: 0.8123 - val_loss: 1.0492 - val_acc: 0.6739
# Epoch 26/100
# 0s - loss: 0.4902 - acc: 0.8178 - val_loss: 0.9698 - val_acc: 0.6685
# Epoch 27/100
# 0s - loss: 0.4783 - acc: 0.8378 - val_loss: 0.8203 - val_acc: 0.7391
# Epoch 28/100
# 0s - loss: 0.4834 - acc: 0.8232 - val_loss: 0.8878 - val_acc: 0.7337
# Epoch 29/100
# 0s - loss: 0.4532 - acc: 0.8408 - val_loss: 0.7904 - val_acc: 0.7663
# Epoch 30/100
# 0s - loss: 0.4374 - acc: 0.8396 - val_loss: 0.9230 - val_acc: 0.7283
# Epoch 31/100
# 0s - loss: 0.4268 - acc: 0.8565 - val_loss: 0.7548 - val_acc: 0.7283
# Epoch 32/100
# 0s - loss: 0.4173 - acc: 0.8499 - val_loss: 0.7877 - val_acc: 0.7500
# Epoch 33/100
# 0s - loss: 0.3946 - acc: 0.8680 - val_loss: 0.9258 - val_acc: 0.7065
# Epoch 34/100
# 0s - loss: 0.3834 - acc: 0.8638 - val_loss: 0.8889 - val_acc: 0.6902
# Epoch 35/100
# 0s - loss: 0.3920 - acc: 0.8638 - val_loss: 0.9508 - val_acc: 0.7337
# Epoch 36/100
# 0s - loss: 0.3633 - acc: 0.8680 - val_loss: 0.9227 - val_acc: 0.7391
# Epoch 37/100
# 0s - loss: 0.3722 - acc: 0.8717 - val_loss: 0.9566 - val_acc: 0.6793
# Epoch 38/100
# 0s - loss: 0.3650 - acc: 0.8674 - val_loss: 0.8363 - val_acc: 0.7228
# Epoch 39/100
# 0s - loss: 0.3382 - acc: 0.8880 - val_loss: 0.8261 - val_acc: 0.7446
# Epoch 40/100
# 0s - loss: 0.3085 - acc: 0.9068 - val_loss: 0.9151 - val_acc: 0.7065
# Epoch 41/100
# 0s - loss: 0.3255 - acc: 0.8886 - val_loss: 1.0382 - val_acc: 0.6739
# Epoch 42/100
# 0s - loss: 0.3388 - acc: 0.8759 - val_loss: 1.1943 - val_acc: 0.6304
# Epoch 43/100
# 0s - loss: 0.3357 - acc: 0.8801 - val_loss: 0.9577 - val_acc: 0.7011
# Epoch 44/100
# 0s - loss: 0.3117 - acc: 0.8935 - val_loss: 0.8397 - val_acc: 0.7174
# Epoch 45/100
# 0s - loss: 0.3012 - acc: 0.8904 - val_loss: 0.8454 - val_acc: 0.7717
# Epoch 46/100
# 0s - loss: 0.2703 - acc: 0.9116 - val_loss: 1.1082 - val_acc: 0.6685
# Epoch 47/100
# 0s - loss: 0.2964 - acc: 0.8910 - val_loss: 1.0795 - val_acc: 0.6576
# Epoch 48/100
# 0s - loss: 0.2946 - acc: 0.8892 - val_loss: 0.8308 - val_acc: 0.7120
# Epoch 49/100
# 0s - loss: 0.2707 - acc: 0.9007 - val_loss: 1.0251 - val_acc: 0.6957
# Epoch 50/100
# 0s - loss: 0.2542 - acc: 0.9177 - val_loss: 0.8905 - val_acc: 0.7391
# Epoch 51/100
# 0s - loss: 0.2402 - acc: 0.9201 - val_loss: 0.9840 - val_acc: 0.7228
# Epoch 52/100
# 0s - loss: 0.2341 - acc: 0.9262 - val_loss: 0.9513 - val_acc: 0.7446
# Epoch 53/100
# 0s - loss: 0.2192 - acc: 0.9219 - val_loss: 0.9156 - val_acc: 0.7391
# Epoch 54/100
# 0s - loss: 0.2115 - acc: 0.9334 - val_loss: 1.0274 - val_acc: 0.7011
# Epoch 55/100
# 0s - loss: 0.2156 - acc: 0.9225 - val_loss: 0.9540 - val_acc: 0.7228
# Epoch 56/100
# 0s - loss: 0.1885 - acc: 0.9431 - val_loss: 0.9839 - val_acc: 0.7446
# Epoch 57/100
# 0s - loss: 0.1984 - acc: 0.9340 - val_loss: 1.1143 - val_acc: 0.6630
# Epoch 58/100
# 0s - loss: 0.1864 - acc: 0.9407 - val_loss: 0.9979 - val_acc: 0.7391
# Epoch 59/100
# 0s - loss: 0.1754 - acc: 0.9461 - val_loss: 0.9416 - val_acc: 0.6957
# Epoch 60/100
# 0s - loss: 0.2054 - acc: 0.9328 - val_loss: 0.9396 - val_acc: 0.7120
# Epoch 61/100
# 0s - loss: 0.1855 - acc: 0.9389 - val_loss: 1.0140 - val_acc: 0.6957
# Epoch 62/100
# 0s - loss: 0.1648 - acc: 0.9528 - val_loss: 0.9987 - val_acc: 0.7554
# Epoch 63/100
# 0s - loss: 0.1650 - acc: 0.9473 - val_loss: 1.0272 - val_acc: 0.7174
# Epoch 64/100
# 0s - loss: 0.1730 - acc: 0.9449 - val_loss: 1.0999 - val_acc: 0.7283
# Epoch 65/100
# 0s - loss: 0.1615 - acc: 0.9504 - val_loss: 1.0632 - val_acc: 0.7554
# Epoch 66/100
# 0s - loss: 0.1729 - acc: 0.9467 - val_loss: 1.0298 - val_acc: 0.7283
# Epoch 67/100
# 0s - loss: 0.1548 - acc: 0.9534 - val_loss: 1.2738 - val_acc: 0.7065
# Epoch 68/100
# 0s - loss: 0.1570 - acc: 0.9534 - val_loss: 0.9333 - val_acc: 0.7011
# Epoch 69/100
# 0s - loss: 0.1670 - acc: 0.9407 - val_loss: 1.1301 - val_acc: 0.6902
# Epoch 70/100
# 0s - loss: 0.1560 - acc: 0.9510 - val_loss: 1.1251 - val_acc: 0.6902
# Epoch 71/100
# 0s - loss: 0.1315 - acc: 0.9649 - val_loss: 1.1450 - val_acc: 0.7120
# Epoch 72/100
# 0s - loss: 0.1260 - acc: 0.9661 - val_loss: 1.1177 - val_acc: 0.6957
# Epoch 73/100
# 0s - loss: 0.1172 - acc: 0.9679 - val_loss: 1.1329 - val_acc: 0.7065
# Epoch 74/100
# 0s - loss: 0.1409 - acc: 0.9619 - val_loss: 1.2600 - val_acc: 0.6739
# Epoch 75/100
# 0s - loss: 0.1272 - acc: 0.9600 - val_loss: 1.2717 - val_acc: 0.7065
# Epoch 76/100
# 0s - loss: 0.1331 - acc: 0.9570 - val_loss: 1.0763 - val_acc: 0.7446
# Epoch 77/100
# 0s - loss: 0.1277 - acc: 0.9600 - val_loss: 1.0951 - val_acc: 0.7011
# Epoch 78/100
# 0s - loss: 0.1355 - acc: 0.9546 - val_loss: 1.1497 - val_acc: 0.7011
# Epoch 79/100
# 0s - loss: 0.1372 - acc: 0.9582 - val_loss: 1.1094 - val_acc: 0.7337
# Epoch 80/100
# 0s - loss: 0.1169 - acc: 0.9685 - val_loss: 1.3631 - val_acc: 0.6413
# Epoch 81/100
# 0s - loss: 0.1341 - acc: 0.9546 - val_loss: 1.1411 - val_acc: 0.7065
# Epoch 82/100
# 0s - loss: 0.1314 - acc: 0.9643 - val_loss: 1.0878 - val_acc: 0.7174
# Epoch 83/100
# 0s - loss: 0.1276 - acc: 0.9607 - val_loss: 1.1540 - val_acc: 0.7337
# Epoch 84/100
# 0s - loss: 0.1084 - acc: 0.9691 - val_loss: 1.2336 - val_acc: 0.7174
# Epoch 85/100
# 0s - loss: 0.1159 - acc: 0.9649 - val_loss: 1.1335 - val_acc: 0.7011
# Epoch 86/100
# 0s - loss: 0.1147 - acc: 0.9667 - val_loss: 1.2342 - val_acc: 0.6522
# Epoch 87/100
# 0s - loss: 0.1060 - acc: 0.9667 - val_loss: 1.2017 - val_acc: 0.7065
# Epoch 88/100
# 0s - loss: 0.0921 - acc: 0.9740 - val_loss: 1.2366 - val_acc: 0.7228
# Epoch 89/100
# 0s - loss: 0.0837 - acc: 0.9782 - val_loss: 1.1564 - val_acc: 0.7391
# Epoch 90/100
# 0s - loss: 0.1016 - acc: 0.9679 - val_loss: 1.3106 - val_acc: 0.7120
# Epoch 91/100
# 0s - loss: 0.0923 - acc: 0.9709 - val_loss: 1.2034 - val_acc: 0.7065
# Epoch 92/100
# 0s - loss: 0.0956 - acc: 0.9734 - val_loss: 1.3809 - val_acc: 0.6630
# Epoch 93/100
# 0s - loss: 0.1048 - acc: 0.9722 - val_loss: 1.4102 - val_acc: 0.6576
# Epoch 94/100
# 0s - loss: 0.1164 - acc: 0.9607 - val_loss: 1.2320 - val_acc: 0.7337
# Epoch 95/100
# 0s - loss: 0.0934 - acc: 0.9740 - val_loss: 1.3054 - val_acc: 0.7120
# Epoch 96/100
# 0s - loss: 0.0971 - acc: 0.9728 - val_loss: 1.3248 - val_acc: 0.7283
# Epoch 97/100
# 0s - loss: 0.1000 - acc: 0.9740 - val_loss: 1.2958 - val_acc: 0.7065
# Epoch 98/100
# 0s - loss: 0.1113 - acc: 0.9619 - val_loss: 1.1982 - val_acc: 0.7283
# Epoch 99/100
# 0s - loss: 0.0884 - acc: 0.9728 - val_loss: 1.3763 - val_acc: 0.6848
# Epoch 100/100
# 0s - loss: 0.0873 - acc: 0.9776 - val_loss: 1.2600 - val_acc: 0.7446
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 1s - loss: 1.6666 - acc: 0.3862 - val_loss: 1.9311 - val_acc: 0.5326
# Epoch 2/100
# 0s - loss: 1.4239 - acc: 0.5018 - val_loss: 1.3223 - val_acc: 0.5598
# Epoch 3/100
# 0s - loss: 1.3599 - acc: 0.5127 - val_loss: 1.1068 - val_acc: 0.6141
# Epoch 4/100
# 0s - loss: 1.2484 - acc: 0.5502 - val_loss: 0.9710 - val_acc: 0.6304
# Epoch 5/100
# 0s - loss: 1.2375 - acc: 0.5569 - val_loss: 0.9255 - val_acc: 0.6630
# Epoch 6/100
# 0s - loss: 1.2010 - acc: 0.5745 - val_loss: 0.9122 - val_acc: 0.6685
# Epoch 7/100
# 0s - loss: 1.1397 - acc: 0.5884 - val_loss: 0.9418 - val_acc: 0.6685
# Epoch 8/100
# 0s - loss: 1.0830 - acc: 0.6114 - val_loss: 0.8607 - val_acc: 0.7011
# Epoch 9/100
# 0s - loss: 1.0526 - acc: 0.6053 - val_loss: 0.8751 - val_acc: 0.7228
# Epoch 10/100
# 0s - loss: 1.0412 - acc: 0.6423 - val_loss: 0.8428 - val_acc: 0.6957
# Epoch 11/100
# 0s - loss: 1.0134 - acc: 0.6326 - val_loss: 0.8760 - val_acc: 0.6848
# Epoch 12/100
# 0s - loss: 0.9732 - acc: 0.6598 - val_loss: 0.8673 - val_acc: 0.6957
# Epoch 13/100
# 0s - loss: 1.0043 - acc: 0.6525 - val_loss: 0.8752 - val_acc: 0.6902
# Epoch 14/100
# 0s - loss: 0.9677 - acc: 0.6495 - val_loss: 0.8053 - val_acc: 0.7337
# Epoch 15/100
# 0s - loss: 0.9359 - acc: 0.6755 - val_loss: 0.7871 - val_acc: 0.7011
# Epoch 16/100
# 0s - loss: 0.9378 - acc: 0.6683 - val_loss: 0.7912 - val_acc: 0.7174
# Epoch 17/100
# 0s - loss: 0.9315 - acc: 0.6677 - val_loss: 0.8133 - val_acc: 0.6957
# Epoch 18/100
# 0s - loss: 0.9120 - acc: 0.6731 - val_loss: 0.7728 - val_acc: 0.7337
# Epoch 19/100
# 0s - loss: 0.9041 - acc: 0.6695 - val_loss: 0.7577 - val_acc: 0.7228
# Epoch 20/100
# 0s - loss: 0.9018 - acc: 0.6883 - val_loss: 0.7490 - val_acc: 0.7391
# Epoch 21/100
# 0s - loss: 0.8710 - acc: 0.6883 - val_loss: 0.7742 - val_acc: 0.7446
# Epoch 22/100
# 0s - loss: 0.8689 - acc: 0.6877 - val_loss: 0.7405 - val_acc: 0.7228
# Epoch 23/100
# 0s - loss: 0.8867 - acc: 0.6883 - val_loss: 0.8144 - val_acc: 0.7120
# Epoch 24/100
# 0s - loss: 0.8699 - acc: 0.6979 - val_loss: 0.7650 - val_acc: 0.7446
# Epoch 25/100
# 0s - loss: 0.8589 - acc: 0.6937 - val_loss: 0.7242 - val_acc: 0.7554
# Epoch 26/100
# 0s - loss: 0.8662 - acc: 0.6961 - val_loss: 0.7669 - val_acc: 0.7391
# Epoch 27/100
# 0s - loss: 0.8483 - acc: 0.7082 - val_loss: 0.7284 - val_acc: 0.7391
# Epoch 28/100
# 0s - loss: 0.8284 - acc: 0.7125 - val_loss: 0.7259 - val_acc: 0.7554
# Epoch 29/100
# 0s - loss: 0.8245 - acc: 0.7004 - val_loss: 0.7460 - val_acc: 0.7391
# Epoch 30/100
# 0s - loss: 0.8283 - acc: 0.7094 - val_loss: 0.7075 - val_acc: 0.7554
# Epoch 31/100
# 0s - loss: 0.8374 - acc: 0.7094 - val_loss: 0.7027 - val_acc: 0.7446
# Epoch 32/100
# 0s - loss: 0.8238 - acc: 0.7082 - val_loss: 0.7436 - val_acc: 0.7500
# Epoch 33/100
# 0s - loss: 0.8001 - acc: 0.7209 - val_loss: 0.6946 - val_acc: 0.7391
# Epoch 34/100
# 0s - loss: 0.8026 - acc: 0.7143 - val_loss: 0.6885 - val_acc: 0.7446
# Epoch 35/100
# 0s - loss: 0.8103 - acc: 0.7191 - val_loss: 0.6942 - val_acc: 0.7500
# Epoch 36/100
# 0s - loss: 0.7993 - acc: 0.7088 - val_loss: 0.6717 - val_acc: 0.7500
# Epoch 37/100
# 0s - loss: 0.8117 - acc: 0.7119 - val_loss: 0.7385 - val_acc: 0.7554
# Epoch 38/100
# 0s - loss: 0.8044 - acc: 0.7179 - val_loss: 0.7982 - val_acc: 0.7337
# Epoch 39/100
# 0s - loss: 0.7835 - acc: 0.7191 - val_loss: 0.6824 - val_acc: 0.7554
# Epoch 40/100
# 0s - loss: 0.7858 - acc: 0.7203 - val_loss: 0.6868 - val_acc: 0.7609
# Epoch 41/100
# 0s - loss: 0.7851 - acc: 0.7167 - val_loss: 0.7018 - val_acc: 0.7663
# Epoch 42/100
# 0s - loss: 0.7833 - acc: 0.7240 - val_loss: 0.7010 - val_acc: 0.7717
# Epoch 43/100
# 0s - loss: 0.7766 - acc: 0.7331 - val_loss: 0.7091 - val_acc: 0.7609
# Epoch 44/100
# 0s - loss: 0.7779 - acc: 0.7185 - val_loss: 0.6990 - val_acc: 0.7609
# Epoch 45/100
# 0s - loss: 0.7695 - acc: 0.7288 - val_loss: 0.6806 - val_acc: 0.7609
# Epoch 46/100
# 0s - loss: 0.7606 - acc: 0.7355 - val_loss: 0.6660 - val_acc: 0.7609
# Epoch 47/100
# 0s - loss: 0.7416 - acc: 0.7421 - val_loss: 0.6713 - val_acc: 0.7772
# Epoch 48/100
# 0s - loss: 0.7295 - acc: 0.7446 - val_loss: 0.6434 - val_acc: 0.7609
# Epoch 49/100
# 0s - loss: 0.7676 - acc: 0.7234 - val_loss: 0.7289 - val_acc: 0.7337
# Epoch 50/100
# 0s - loss: 0.7579 - acc: 0.7385 - val_loss: 0.6509 - val_acc: 0.7772
# Epoch 51/100
# 0s - loss: 0.7457 - acc: 0.7343 - val_loss: 0.6633 - val_acc: 0.7772
# Epoch 52/100
# 0s - loss: 0.7417 - acc: 0.7318 - val_loss: 0.6241 - val_acc: 0.7772
# Epoch 53/100
# 0s - loss: 0.7321 - acc: 0.7409 - val_loss: 0.6893 - val_acc: 0.7500
# Epoch 54/100
# 0s - loss: 0.7035 - acc: 0.7373 - val_loss: 0.6598 - val_acc: 0.7609
# Epoch 55/100
# 0s - loss: 0.7079 - acc: 0.7506 - val_loss: 0.6389 - val_acc: 0.7880
# Epoch 56/100
# 0s - loss: 0.7105 - acc: 0.7506 - val_loss: 0.6879 - val_acc: 0.7663
# Epoch 57/100
# 0s - loss: 0.6972 - acc: 0.7573 - val_loss: 0.6732 - val_acc: 0.7500
# Epoch 58/100
# 0s - loss: 0.7083 - acc: 0.7427 - val_loss: 0.6298 - val_acc: 0.7772
# Epoch 59/100
# 0s - loss: 0.7388 - acc: 0.7355 - val_loss: 0.6564 - val_acc: 0.7554
# Epoch 60/100
# 0s - loss: 0.7351 - acc: 0.7391 - val_loss: 0.6573 - val_acc: 0.7554
# Epoch 61/100
# 0s - loss: 0.7114 - acc: 0.7500 - val_loss: 0.6495 - val_acc: 0.7554
# Epoch 62/100
# 0s - loss: 0.7174 - acc: 0.7530 - val_loss: 0.6413 - val_acc: 0.7663
# Epoch 63/100
# 0s - loss: 0.7293 - acc: 0.7446 - val_loss: 0.6162 - val_acc: 0.7880
# Epoch 64/100
# 0s - loss: 0.6909 - acc: 0.7536 - val_loss: 0.6104 - val_acc: 0.7826
# Epoch 65/100
# 0s - loss: 0.6759 - acc: 0.7597 - val_loss: 0.6215 - val_acc: 0.7772
# Epoch 66/100
# 0s - loss: 0.7078 - acc: 0.7439 - val_loss: 0.6248 - val_acc: 0.7772
# Epoch 67/100
# 0s - loss: 0.7011 - acc: 0.7470 - val_loss: 0.6688 - val_acc: 0.7663
# Epoch 68/100
# 0s - loss: 0.6783 - acc: 0.7488 - val_loss: 0.6351 - val_acc: 0.7663
# Epoch 69/100
# 0s - loss: 0.6806 - acc: 0.7579 - val_loss: 0.6074 - val_acc: 0.7935
# Epoch 70/100
# 0s - loss: 0.6818 - acc: 0.7688 - val_loss: 0.6402 - val_acc: 0.7446
# Epoch 71/100
# 0s - loss: 0.6729 - acc: 0.7603 - val_loss: 0.6020 - val_acc: 0.7989
# Epoch 72/100
# 0s - loss: 0.6626 - acc: 0.7657 - val_loss: 0.6399 - val_acc: 0.7772
# Epoch 73/100
# 0s - loss: 0.6704 - acc: 0.7627 - val_loss: 0.6215 - val_acc: 0.7772
# Epoch 74/100
# 0s - loss: 0.6758 - acc: 0.7627 - val_loss: 0.6561 - val_acc: 0.7500
# Epoch 75/100
# 0s - loss: 0.6804 - acc: 0.7627 - val_loss: 0.6740 - val_acc: 0.7609
# Epoch 76/100
# 0s - loss: 0.6624 - acc: 0.7585 - val_loss: 0.6571 - val_acc: 0.7880
# Epoch 77/100
# 0s - loss: 0.6760 - acc: 0.7597 - val_loss: 0.7046 - val_acc: 0.7500
# Epoch 78/100
# 0s - loss: 0.6806 - acc: 0.7506 - val_loss: 0.6744 - val_acc: 0.7663
# Epoch 79/100
# 0s - loss: 0.6681 - acc: 0.7615 - val_loss: 0.6192 - val_acc: 0.7826
# Epoch 80/100
# 0s - loss: 0.6606 - acc: 0.7676 - val_loss: 0.6718 - val_acc: 0.7554
# Epoch 81/100
# 0s - loss: 0.6831 - acc: 0.7633 - val_loss: 0.6223 - val_acc: 0.7935
# Epoch 82/100
# 0s - loss: 0.6485 - acc: 0.7712 - val_loss: 0.6001 - val_acc: 0.7772
# Epoch 83/100
# 0s - loss: 0.6593 - acc: 0.7663 - val_loss: 0.7044 - val_acc: 0.7500
# Epoch 84/100
# 0s - loss: 0.6589 - acc: 0.7700 - val_loss: 0.6567 - val_acc: 0.7554
# Epoch 85/100
# 0s - loss: 0.6466 - acc: 0.7730 - val_loss: 0.6150 - val_acc: 0.7935
# Epoch 86/100
# 0s - loss: 0.6528 - acc: 0.7585 - val_loss: 0.6229 - val_acc: 0.7717
# Epoch 87/100
# 0s - loss: 0.6603 - acc: 0.7682 - val_loss: 0.6092 - val_acc: 0.7663
# Epoch 88/100
# 0s - loss: 0.6451 - acc: 0.7700 - val_loss: 0.6175 - val_acc: 0.7609
# Epoch 89/100
# 0s - loss: 0.6448 - acc: 0.7809 - val_loss: 0.6298 - val_acc: 0.7717
# Epoch 90/100
# 0s - loss: 0.6362 - acc: 0.7609 - val_loss: 0.6307 - val_acc: 0.7554
# Epoch 91/100
# 0s - loss: 0.6635 - acc: 0.7579 - val_loss: 0.7249 - val_acc: 0.7391
# Epoch 92/100
# 0s - loss: 0.6528 - acc: 0.7682 - val_loss: 0.6657 - val_acc: 0.7446
# Epoch 93/100
# 0s - loss: 0.6479 - acc: 0.7633 - val_loss: 0.6058 - val_acc: 0.7717
# Epoch 94/100
# 0s - loss: 0.6296 - acc: 0.7754 - val_loss: 0.6449 - val_acc: 0.7663
# Epoch 95/100
# 0s - loss: 0.6265 - acc: 0.7766 - val_loss: 0.6110 - val_acc: 0.8043
# Epoch 96/100
# 0s - loss: 0.6345 - acc: 0.7633 - val_loss: 0.6415 - val_acc: 0.7554
# Epoch 97/100
# 0s - loss: 0.6460 - acc: 0.7688 - val_loss: 0.6527 - val_acc: 0.7337
# Epoch 98/100
# 0s - loss: 0.6384 - acc: 0.7785 - val_loss: 0.6386 - val_acc: 0.7609
# Epoch 99/100
# 0s - loss: 0.6424 - acc: 0.7639 - val_loss: 0.6402 - val_acc: 0.7500
# Epoch 100/100
# 0s - loss: 0.6226 - acc: 0.7663 - val_loss: 0.6424 - val_acc: 0.7283
# Train on 1652 samples, validate on 184 samples
# Epoch 1/100
# 7s - loss: 1.4510 - acc: 0.4849 - val_loss: 1.5149 - val_acc: 0.4130
# Epoch 2/100
# 6s - loss: 1.3910 - acc: 0.4933 - val_loss: 1.6057 - val_acc: 0.4946
# Epoch 3/100
# 6s - loss: 1.3765 - acc: 0.5079 - val_loss: 1.3822 - val_acc: 0.5598
# Epoch 4/100
# 6s - loss: 1.3524 - acc: 0.5109 - val_loss: 1.3642 - val_acc: 0.5217
# Epoch 5/100
# 6s - loss: 1.3515 - acc: 0.5169 - val_loss: 1.3425 - val_acc: 0.5000
# Epoch 6/100
# 6s - loss: 1.3695 - acc: 0.5151 - val_loss: 1.2458 - val_acc: 0.5870
# Epoch 7/100
# 6s - loss: 1.3572 - acc: 0.5151 - val_loss: 1.3378 - val_acc: 0.5380
# Epoch 8/100
# 6s - loss: 1.3500 - acc: 0.5236 - val_loss: 1.2798 - val_acc: 0.5652
# Epoch 9/100
# 6s - loss: 1.3395 - acc: 0.5169 - val_loss: 1.2770 - val_acc: 0.6033
# Epoch 10/100
# 6s - loss: 1.3393 - acc: 0.5200 - val_loss: 1.1253 - val_acc: 0.5870
# Epoch 11/100
# 6s - loss: 1.3174 - acc: 0.5218 - val_loss: 1.1752 - val_acc: 0.6467
# Epoch 12/100
# 6s - loss: 1.3341 - acc: 0.5127 - val_loss: 1.1019 - val_acc: 0.6250
# Epoch 13/100
# 6s - loss: 1.3196 - acc: 0.5212 - val_loss: 1.2310 - val_acc: 0.6196
# Epoch 14/100
# 6s - loss: 1.3200 - acc: 0.5260 - val_loss: 1.1317 - val_acc: 0.6304
# Epoch 15/100
# 6s - loss: 1.3142 - acc: 0.5218 - val_loss: 1.2270 - val_acc: 0.6196
# Epoch 16/100
# 6s - loss: 1.3061 - acc: 0.5182 - val_loss: 1.1864 - val_acc: 0.6413
# Epoch 17/100
# 6s - loss: 1.3273 - acc: 0.5176 - val_loss: 1.2052 - val_acc: 0.6087
# Epoch 18/100
# 6s - loss: 1.3146 - acc: 0.5285 - val_loss: 1.1743 - val_acc: 0.6250
# Epoch 19/100
# 6s - loss: 1.3120 - acc: 0.5297 - val_loss: 1.1849 - val_acc: 0.6196
# Epoch 20/100
# 6s - loss: 1.3094 - acc: 0.5266 - val_loss: 1.1674 - val_acc: 0.6304
# Epoch 21/100
# 6s - loss: 1.2921 - acc: 0.5272 - val_loss: 1.0688 - val_acc: 0.6576
# Epoch 22/100
# 6s - loss: 1.3026 - acc: 0.5218 - val_loss: 1.1853 - val_acc: 0.6087
# Epoch 23/100
# 6s - loss: 1.2991 - acc: 0.5315 - val_loss: 1.0876 - val_acc: 0.6467
# Epoch 24/100
# 6s - loss: 1.3260 - acc: 0.5127 - val_loss: 1.1538 - val_acc: 0.6141
# Epoch 25/100
# 6s - loss: 1.3019 - acc: 0.5278 - val_loss: 1.1734 - val_acc: 0.6141
# Epoch 26/100
# 6s - loss: 1.2908 - acc: 0.5260 - val_loss: 1.1045 - val_acc: 0.6196
# Epoch 27/100
# 6s - loss: 1.2874 - acc: 0.5224 - val_loss: 1.1599 - val_acc: 0.6304
# Epoch 28/100
# 6s - loss: 1.2876 - acc: 0.5303 - val_loss: 1.1421 - val_acc: 0.6522
# Epoch 29/100
# 6s - loss: 1.2974 - acc: 0.5260 - val_loss: 1.1266 - val_acc: 0.6359
# Epoch 30/100
# 7s - loss: 1.3047 - acc: 0.5260 - val_loss: 1.1715 - val_acc: 0.6359
# Epoch 31/100
# 6s - loss: 1.2962 - acc: 0.5266 - val_loss: 1.1529 - val_acc: 0.6141
# Epoch 32/100
# 6s - loss: 1.2804 - acc: 0.5345 - val_loss: 1.0904 - val_acc: 0.6413
# Epoch 33/100
# 6s - loss: 1.2923 - acc: 0.5236 - val_loss: 1.0874 - val_acc: 0.6250
# Epoch 34/100
# 6s - loss: 1.2876 - acc: 0.5297 - val_loss: 1.0529 - val_acc: 0.6033
# Epoch 35/100
# 6s - loss: 1.2878 - acc: 0.5218 - val_loss: 1.1142 - val_acc: 0.6304
# Epoch 36/100
# 6s - loss: 1.2750 - acc: 0.5291 - val_loss: 1.1058 - val_acc: 0.6304
# Epoch 37/100
# 6s - loss: 1.2814 - acc: 0.5333 - val_loss: 1.1162 - val_acc: 0.6250
# Epoch 38/100
# 6s - loss: 1.2849 - acc: 0.5321 - val_loss: 1.1384 - val_acc: 0.6467
# Epoch 39/100
# 6s - loss: 1.2734 - acc: 0.5351 - val_loss: 1.0711 - val_acc: 0.6359
# Epoch 40/100
# 6s - loss: 1.2833 - acc: 0.5321 - val_loss: 1.0227 - val_acc: 0.6359
# Epoch 41/100
# 6s - loss: 1.2773 - acc: 0.5393 - val_loss: 1.0811 - val_acc: 0.6250
# Epoch 42/100
# 6s - loss: 1.2924 - acc: 0.5254 - val_loss: 1.0462 - val_acc: 0.6304
# Epoch 43/100
# 6s - loss: 1.2746 - acc: 0.5254 - val_loss: 1.0387 - val_acc: 0.6413
# Epoch 44/100
# 6s - loss: 1.2666 - acc: 0.5339 - val_loss: 1.0327 - val_acc: 0.6467
# Epoch 45/100
# 6s - loss: 1.2687 - acc: 0.5357 - val_loss: 0.9693 - val_acc: 0.6359
# Epoch 46/100
# 6s - loss: 1.2763 - acc: 0.5363 - val_loss: 1.0790 - val_acc: 0.6413
# Epoch 47/100
# 6s - loss: 1.2684 - acc: 0.5363 - val_loss: 1.0236 - val_acc: 0.6359
# Epoch 48/100
# 6s - loss: 1.2739 - acc: 0.5278 - val_loss: 1.0140 - val_acc: 0.6304
# Epoch 49/100
# 6s - loss: 1.2532 - acc: 0.5436 - val_loss: 0.9812 - val_acc: 0.6413
# Epoch 50/100
# 6s - loss: 1.2769 - acc: 0.5297 - val_loss: 1.0164 - val_acc: 0.6630
# Epoch 51/100
# 6s - loss: 1.2893 - acc: 0.5321 - val_loss: 1.0212 - val_acc: 0.6359
# Epoch 52/100
# 6s - loss: 1.2786 - acc: 0.5303 - val_loss: 1.0011 - val_acc: 0.6467
# Epoch 53/100
# 6s - loss: 1.2765 - acc: 0.5327 - val_loss: 1.0230 - val_acc: 0.6359
# Epoch 54/100
# 6s - loss: 1.2471 - acc: 0.5448 - val_loss: 1.0107 - val_acc: 0.6685
# Epoch 55/100
# 6s - loss: 1.2875 - acc: 0.5291 - val_loss: 1.0728 - val_acc: 0.6196
# Epoch 56/100
# 6s - loss: 1.2640 - acc: 0.5315 - val_loss: 0.9998 - val_acc: 0.6576
# Epoch 57/100
# 6s - loss: 1.2693 - acc: 0.5309 - val_loss: 0.9947 - val_acc: 0.6413
# Epoch 58/100
# 6s - loss: 1.2564 - acc: 0.5357 - val_loss: 0.9929 - val_acc: 0.6304
# Epoch 59/100
# 6s - loss: 1.2668 - acc: 0.5357 - val_loss: 1.0309 - val_acc: 0.6359
# Epoch 60/100
# 7s - loss: 1.2708 - acc: 0.5351 - val_loss: 1.0857 - val_acc: 0.6413
# Epoch 61/100
# 7s - loss: 1.2684 - acc: 0.5327 - val_loss: 1.0991 - val_acc: 0.6196
# Epoch 62/100
# 6s - loss: 1.2667 - acc: 0.5333 - val_loss: 1.0297 - val_acc: 0.6630
# Epoch 63/100
# 6s - loss: 1.2579 - acc: 0.5448 - val_loss: 0.9999 - val_acc: 0.6359
# Epoch 64/100
# 6s - loss: 1.2491 - acc: 0.5418 - val_loss: 1.0276 - val_acc: 0.6304
# Epoch 65/100
# 6s - loss: 1.2660 - acc: 0.5345 - val_loss: 1.0085 - val_acc: 0.6359
# Epoch 66/100
# 6s - loss: 1.2434 - acc: 0.5442 - val_loss: 1.0438 - val_acc: 0.6250
# Epoch 67/100
# 6s - loss: 1.2718 - acc: 0.5387 - val_loss: 1.0619 - val_acc: 0.6141
# Epoch 68/100
# 6s - loss: 1.2722 - acc: 0.5254 - val_loss: 1.0616 - val_acc: 0.6250
# Epoch 69/100
# 6s - loss: 1.2581 - acc: 0.5321 - val_loss: 1.0117 - val_acc: 0.6196
# Epoch 70/100
# 6s - loss: 1.2766 - acc: 0.5236 - val_loss: 0.9947 - val_acc: 0.6413
# Epoch 71/100
# 7s - loss: 1.2464 - acc: 0.5339 - val_loss: 1.0169 - val_acc: 0.6304
# Epoch 72/100
# 6s - loss: 1.2603 - acc: 0.5297 - val_loss: 0.9957 - val_acc: 0.6250
# Epoch 73/100
# 6s - loss: 1.2502 - acc: 0.5454 - val_loss: 1.0189 - val_acc: 0.6413
# Epoch 74/100
# 6s - loss: 1.2463 - acc: 0.5357 - val_loss: 0.9575 - val_acc: 0.6522
# Epoch 75/100
# 6s - loss: 1.2575 - acc: 0.5351 - val_loss: 0.9973 - val_acc: 0.6467
# Epoch 76/100
# 6s - loss: 1.2819 - acc: 0.5381 - val_loss: 0.9840 - val_acc: 0.6359
# Epoch 77/100
# 6s - loss: 1.2571 - acc: 0.5351 - val_loss: 1.0039 - val_acc: 0.6685
# Epoch 78/100
# 6s - loss: 1.2556 - acc: 0.5375 - val_loss: 0.9649 - val_acc: 0.6793
# Epoch 79/100
# 6s - loss: 1.2558 - acc: 0.5424 - val_loss: 1.0004 - val_acc: 0.6685
# Epoch 80/100
# 6s - loss: 1.2515 - acc: 0.5448 - val_loss: 1.0670 - val_acc: 0.6793
# Epoch 81/100
# 6s - loss: 1.2708 - acc: 0.5418 - val_loss: 1.0537 - val_acc: 0.6359
# Epoch 82/100
# 6s - loss: 1.2508 - acc: 0.5333 - val_loss: 1.0260 - val_acc: 0.6576
# Epoch 83/100
# 6s - loss: 1.2655 - acc: 0.5393 - val_loss: 1.0333 - val_acc: 0.6304
# Epoch 84/100
# 6s - loss: 1.2611 - acc: 0.5291 - val_loss: 1.0060 - val_acc: 0.6467
# Epoch 85/100
# 6s - loss: 1.2482 - acc: 0.5436 - val_loss: 1.0547 - val_acc: 0.6413
# Epoch 86/100
# 6s - loss: 1.2603 - acc: 0.5472 - val_loss: 0.9978 - val_acc: 0.6413
# Epoch 87/100
# 6s - loss: 1.2620 - acc: 0.5387 - val_loss: 1.0363 - val_acc: 0.6359
# Epoch 88/100
# 6s - loss: 1.2575 - acc: 0.5339 - val_loss: 0.9924 - val_acc: 0.6630
# Epoch 89/100
# 7s - loss: 1.2589 - acc: 0.5357 - val_loss: 1.0286 - val_acc: 0.6576
# Epoch 90/100
# 7s - loss: 1.2614 - acc: 0.5400 - val_loss: 1.0772 - val_acc: 0.6685
# Epoch 91/100
# 9s - loss: 1.2768 - acc: 0.5272 - val_loss: 1.0353 - val_acc: 0.6630
# Epoch 92/100
# 7s - loss: 1.2622 - acc: 0.5424 - val_loss: 1.0106 - val_acc: 0.6848
# Epoch 93/100
# 7s - loss: 1.2655 - acc: 0.5339 - val_loss: 1.0361 - val_acc: 0.6522
# Epoch 94/100
# 7s - loss: 1.2683 - acc: 0.5327 - val_loss: 1.0127 - val_acc: 0.6304
# Epoch 95/100
# 6s - loss: 1.2656 - acc: 0.5345 - val_loss: 1.0246 - val_acc: 0.6522
# Epoch 96/100
# 7s - loss: 1.2575 - acc: 0.5400 - val_loss: 1.0347 - val_acc: 0.6576
# Epoch 97/100
# 6s - loss: 1.2619 - acc: 0.5351 - val_loss: 1.0152 - val_acc: 0.6848
# Epoch 98/100
# 6s - loss: 1.2616 - acc: 0.5321 - val_loss: 1.0450 - val_acc: 0.6957
# Epoch 99/100
# 6s - loss: 1.2536 - acc: 0.5333 - val_loss: 1.0035 - val_acc: 0.6630
# Epoch 100/100
# 6s - loss: 1.2614 - acc: 0.5321 - val_loss: 0.9967 - val_acc: 0.6739

# %%
''' Visualize the loss and accuracy of both models'''
import matplotlib.pyplot as plt
skp = 10
plt.figure(0)
#plt.subplot(121)
plt.plot(range(len(loss_adam_drp40)), loss_adam_drp40,label='Training_drp40')
plt.plot(range(len(val_loss_adam_drp40)), val_loss_adam_drp40,label='Validation_drp40')

plt.plot(range(len(loss_adam_drp40_bn)), loss_adam_drp40_bn,label='Training_drp40_bn')
plt.plot(range(len(val_loss_adam_drp40_bn)), val_loss_adam_drp40_bn,label='Validation_drp40_bn')

plt.plot(range(len(loss_adam_bn)), loss_adam_bn,label='Training_bn')
plt.plot(range(len(val_loss_adam_bn)), val_loss_adam_bn,label='Validation_bn')

plt.plot(range(len(loss_adam_bn_ks)), loss_adam_bn_ks,label='Training_bn (bz=2)')
plt.plot(range(len(val_loss_adam_bn_ks)), val_loss_adam_bn_ks,label='Validation_bn (bz=2)')


plt.legend(loc = 2, ncol = 2, fontsize = 8)
plt.title('Loss')
#plt.savefig('09_bn_vs_dropout_loss.png',dpi=300,format='png')
#plt.close()
plt.show()

plt.plot(range(len(acc_adam_drp40)), 
         acc_adam_drp40,
         label='Training_drp40')
plt.plot(range(len(val_acc_adam_drp40)), 
         val_acc_adam_drp40,
         label='Validation_drp40')
plt.plot(range(len(acc_adam_drp40_bn)), 
         acc_adam_drp40_bn,
         label='Training_drp40_bn')
plt.plot(range(len(val_acc_adam_drp40_bn)), 
         val_acc_adam_drp40_bn,
         label='Validation_drp40_bn')
plt.plot(range(len(acc_adam_bn)), 
         acc_adam_bn,
         label='Training_bn')
plt.plot(range(len(val_acc_adam_bn)), 
         val_acc_adam_bn,
         label='Validation_bn')
plt.plot(range(len(acc_adam_bn_ks)), 
         acc_adam_bn_ks,
         label='Training_bn (bz=2)')
plt.plot(range(len(val_acc_adam_bn_ks)), 
         val_acc_adam_bn_ks,
         label='Validation_bn (bz=2)')

plt.legend(loc = 4, ncol = 2, fontsize = 8)
plt.title('Accuracy')
#plt.show()

#plt.savefig('09_bn_vs_dropout_accuracy.png',dpi=300,format='png')
#plt.close()
print('Result saved into 08_dropout_loss/acc.png')
# Out:
# Result saved into 08_dropout_loss/acc.png
